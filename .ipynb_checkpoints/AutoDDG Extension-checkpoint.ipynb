# %%
from google import genai
from autoddg import AutoDDG
import pandas as pd

# Setup OpenAI client
client = genai.Client(api_key="")

# Initialize AutoDDG
autoddg = AutoDDG(client=client, model_name="gemini-2.0-flash")

# Generate description from a small CSV sample
sample_csv = pd.read_csv('')

prompt, description = autoddg.generate_description(dataset_sample=sample_csv)

print(description)
# >>> This dataset contains medical information about patients, including their unique Case_ID, Age, and Body Mass Index (BMI). etc.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3 import pandas as pd
#       5 # Setup OpenAI client
# ----> 6 client = genai.Client(api_key="")
#       8 # Initialize AutoDDG
#       9 autoddg = AutoDDG(client=client, model_name="gemini-2.0-flash")
#
# File /opt/miniconda3/envs/autoddg_geo/lib/python3.11/site-packages/google/genai/client.py:265, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     262   else:
#     263     http_options = HttpOptions(base_url=base_url)
# --> 265 self._api_client = self._get_api_client(
#     266     vertexai=vertexai,
#     267     api_key=api_key,
#     268     credentials=credentials,
#     269     project=project,
#     270     location=location,
#     271     debug_config=self._debug_config,
#     272     http_options=http_options,
#     273 )
# ...

# %%
help(autoddg)
# Out:
# Help on AutoDDG in module autoddg.autoddg object:
#
# class AutoDDG(builtins.object)
#  |  AutoDDG(client: Any, model_name: str, *, description_temperature: float = 0.0, description_words: int = 100, search_model_name: str | None = None, semantic_model_name: str | None = None, topic_temperature: float = 0.0, evaluator: autoddg.evaluation.base.BaseEvaluator | None = None) -> None
#  |
#  |  AutoDDG - Automated Dataset Description Generator
#  |
#  |  AutoDDG is the library's entry class, exposing:
#  |  * profiling,
#  |  * semantic analysis,
#  |  * topic generation,
#  |  * dataset description,
#  |  * search-focused description expansion, and
#  |  * optional description evaluation
#  |
#  |  Args:
#  |      client (Any): OpenAI-compatible client (e.g. ``openai.OpenAI(...)``).
#  |      model_name (str): Default model identifier (e.g. ``"gpt-4o"``).
#  |      description_temperature (float): Temperature for description generation.
# ...

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('locale_dataset.csv')
dataprofile = autoddg.profile_dataframe(dataframe=df)
print(dataprofile)
# Out:
# ('The key data profile information for this dataset includes:\n**PlaceName**: Data is of type text. There are 5 unique values. \n**Latitude**: Data is of type float. Coverage spans from 0 to 40.785091. \n**Longitude**: Data is of type float. Coverage spans from -73.996864 to 0. \n**RegionType**: Data is of type text. There are 4 unique values. \n**PolygonID**: Data is of type text. There are 5 unique values. ', '**Spatial coverage** for columns Latitude, Longitude, with type latlong.')

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key="AIzaSyBaUUM696KvYfr0P-vN0qR64v3v6_zrfNU",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

autoddg = AutoDDG(
    client=client, 
    model_name="gemini-2.0-flash-lite"
)

semanticprofile = autoddg.analyze_semantics(dataframe=df)
print(semanticprofile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       2 import os
#       4 client = OpenAI(
#       5     api_key="AIzaSyBaUUM696KvYfr0P-vN0qR64v3v6_zrfNU",
#       6     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       7 )
# ----> 9 autoddg = AutoDDG(
#      10     client=client,
#      11     model_name="gemini-2.0-flash-lite"
#      12 )
#      14 semanticprofile = autoddg.analyze_semantics(dataframe=df)
#      15 print(semanticprofile)
#
# NameError: name 'AutoDDG' is not defined

# %%
prompt, desc = autoddg.describe_dataset(df.to_csv(index=False), dataprofile[0], True, semanticprofile, True)

print(desc)

print(prompt)
# Out:
# This dataset details various geographic places, providing their names, coordinates, and types. It includes 5 unique place names and 5 unique polygon identifiers, categorizing locations into 4 distinct region types. Latitude values, stored as floats, range from 0 to 40.785091, while float Longitude values span from -73.996864 to 0. Semantically, `PlaceName` represents a named location, serving as an aggregation key. `Latitude` and `Longitude` are geographic coordinates, providing spatial data at a coordinate resolution for measurement. `RegionType` categorizes geographical features, and `PolygonID` uniquely identifies polygons, both offering spatial data at their respective resolutions.
# Answer the question using the following information.
#
# First, consider the dataset sample:
#
# PlaceName,Latitude,Longitude,RegionType,PolygonID
# Central Park,40.785091,-73.968285,Park,poly_001
# Times Square,40.758896,-73.98513,Landmark,poly_002
# ...

# %%
search_desc = autoddg.expand_description_for_search(desc, 'Places in NYC')
print(search_desc)
# Out:
# ("You are given a dataset about the topic Places in NYC, with the following initial description:\n\nThis dataset details various geographic places, providing their names, coordinates, and types. It includes 5 unique place names and 5 unique polygon identifiers, categorizing locations into 4 distinct region types. Latitude values, stored as floats, range from 0 to 40.785091, while float Longitude values span from -73.996864 to 0. Semantically, `PlaceName` represents a named location, serving as an aggregation key. `Latitude` and `Longitude` are geographic coordinates, providing spatial data at a coordinate resolution for measurement. `RegionType` categorizes geographical features, and `PolygonID` uniquely identifies polygons, both offering spatial data at their respective resolutions.\n\nPlease expand the description by including the exact topic. Additionally, add as many related concepts, synonyms, and relevant terms as possible based on the initial description and the topic.\n\nUnli
# ...

# %%
print(search_desc[0])
print("*******")
print(search_desc[1])
# Out:
# You are given a dataset about the topic Places in NYC, with the following initial description:
#
# This dataset details various geographic places, providing their names, coordinates, and types. It includes 5 unique place names and 5 unique polygon identifiers, categorizing locations into 4 distinct region types. Latitude values, stored as floats, range from 0 to 40.785091, while float Longitude values span from -73.996864 to 0. Semantically, `PlaceName` represents a named location, serving as an aggregation key. `Latitude` and `Longitude` are geographic coordinates, providing spatial data at a coordinate resolution for measurement. `RegionType` categorizes geographical features, and `PolygonID` uniquely identifies polygons, both offering spatial data at their respective resolutions.
#
# Please expand the description by including the exact topic. Additionally, add as many related concepts, synonyms, and relevant terms as possible based on the initial description and the topic.
#
# ...

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('sr_dataset.csv')
dataprofile = autoddg.profile_dataframe(dataframe=df)
print(dataprofile[0])
# Out:
# The key data profile information for this dataset includes:
# **unique_key**: Data is of type integer. There are 1 unique values. Coverage spans from 0 to 61782994.0.
# **created_date**: Data is of type text. There are 1 unique values.
# **complaint_type**: Data is of type text. There are 1 unique values.
# **descriptor**: Data is of type text. There are 1 unique values.
# **incident_address**: Data is of type text. There are 1 unique values.
# **street_name**: Data is of type text. There are 1 unique values.
# **cross_street_1**: Data is of type text. There are 1 unique values.
# **cross_street_2**: Data is of type text. There are 1 unique values.
# **incident_zip**: Data is of type integer. There are 1 unique values. Coverage spans from 0 to 10458.0.
# **borough**: Data is of type text. There are 1 unique values.
# **latitude**: Data is of type float. Coverage spans from 0 to 40.865011.
# **longitude**: Data is of type float. Coverage spans from -73.893983 to 0.
# ...

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key="AIzaSyDGrlgsKwP_7tNP3DFX_jpeYTPflP2oYrk",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

autoddg = AutoDDG(
    client=client, 
    model_name="gemini-2.0-flash-lite"
)

semanticprofile = autoddg.analyze_semantics(dataframe=df)
print(semanticprofile)
# Out:
# The key semantic information for this dataset includes:
# **unique_key**: Represents other. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: identification.
# **created_date**: Represents temporal entity. Contains temporal data (resolution: Day). Domain-specific type: general. Function/Usage context: metadata.
# **complaint_type**: Represents complaint. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: public services. Function/Usage context: categorization.
# **descriptor**:
# **incident_address**: Represents location. Contains spatial data (resolution: Street Address). Domain-specific type: public safety. Function/Usage context: descriptive.
# **street_name**: Represents location. Contains spatial data (resolution: Street). Domain-specific type: general. Function/Usage context: descriptive feature.
# ...

# %%
prompt, desc = autoddg.describe_dataset(df.to_csv(index=False), dataprofile[0], True, semanticprofile, True)

print(desc)
print(------------------)
print(prompt)
# Out:
# This dataset contains information about noise complaints. Each entry includes a unique key for identification and the date the complaint was created. The dataset captures the type of complaint, a descriptor, and the incident address. It also provides the street name, cross streets, and the zip code where the incident occurred. Further location details include the borough, latitude, and longitude, along with combined location coordinates. The data's semantic profile reveals that the dataset focuses on location, with columns representing street addresses, zip codes, and boroughs. The dataset also includes temporal data, specifically the date the complaint was created.
#
# Answer the question using the following information.
#
# First, consider the dataset sample:
#
# unique_key,created_date,complaint_type,descriptor,incident_address,street_name,cross_street_1,cross_street_2,incident_zip,borough,latitude,longitude,location
# ...

# %%
search_desc = autoddg.expand_description_for_search(desc, 'Places in NYC')
print(search_desc)

# %%
print(search_desc[0])
print("*******")
print(search_desc[1])

# %%
autoddg.evaluate_description(desc)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 autoddg.evaluate_description(desc)
#
# File <@beartype(autoddg.autoddg.AutoDDG.evaluate_description) at 0x157eb94e0>:31, in evaluate_description(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File /opt/miniconda3/envs/autoddg_geo/lib/python3.11/site-packages/autoddg/autoddg.py:217, in AutoDDG.evaluate_description(self, description)
#     203 """
#     204 Score a description with the configured evaluator
#     205
#    (...)    213     RuntimeError: If no evaluator is set
#     214 """
#     216 if self.evaluator is None:
# --> 217     raise RuntimeError(
#     218         "No evaluator configured for AutoDDG. Provide one via set_evaluator()."
#     219     )
#     220 return self.evaluator.evaluate(description)
#
# ...
