# %% [markdown]
# ### 1. Imports

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from google import genai
from autoddg import AutoDDG
import pandas as pd
from pathlib import Path
from geo_profiler.geo_profiler import GeoProfiler
from geo_profiler.models import GeoProfile
from autoddg_geo import AutoDDGGeo
from openai import OpenAI
import time
from rank_bm25 import BM25Okapi
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2. Setting up Open AI Client, AutoDDG and AutoDDG-Geo

# %%
PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

# Setup OpenAI client
client = OpenAI(
    api_key="",      ## ADD GEMINI_API_KEY_HERE
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# Initialize AutoDDG and AutoDDG Geo
autoddg = AutoDDG(client=client, model_name="gemini-2.5-flash-lite")
autoddg_geo = AutoDDGGeo(client=client, model_name="gemini-2.5-flash-lite")

# %% [markdown]
# ### 3. Reading dataset

# %%
def read_dataset(path: str):
    sample_csv = pd.read_csv(path)
    print(sample_csv.shape)
    return sample_csv

# %% [markdown]
# ### 4. Retrieving data profile

# %%
def infer_data_profile(dataframe: pd.DataFrame) -> str:
    dataprofile = autoddg.profile_dataframe(dataframe=dataframe)
    return dataprofile

# %% [markdown]
# ### 5. Deriving Semantic Profile

# %%
def infer_semantic_profile(dataframe: pd.DataFrame) -> str:
    semantic_profile = autoddg.analyze_semantics(dataframe=dataframe)
    return semantic_profile

# %% [markdown]
# ### 6. Deriving Geo Spatial Profile

# %%
def infer_geo_profile(semantic_profile: str, df: pd.DataFrame) -> GeoProfile: 
    geo_profile = autoddg_geo.analyze_geo(semantic_profile, df)
    return geo_profile

# %% [markdown]
# ### 7. Deriving AutoDDG Description

# %%
def generate_dataset_description(sample_csv, dataprofile, use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic):
    prompt, desc = autoddg.describe_dataset(sample_csv, dataprofile[0], use_data_profile, semantic_profile, use_semantic_profile)
    return desc

# %% [markdown]
# ### 8. Deriving Geo Aware Description

# %%
def generate_geoaware_description(sample_csv, dataprofile, use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic, geo_profile, use_geo_profile):
    geo_desc = autoddg_geo.generate_geoaware_description(sample_csv, dataprofile[0], use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic, geo_profile, use_geo_profile)
    return geo_desc[0]

# %% [markdown]
# ### 9. Expanding Geo Aware Description for Search

# %%
def generate_description_for_search(desc, topic):
    search_desc = autoddg.expand_description_for_search(desc, topic)
    return search_desc[1]

# %% [markdown]
# ### 10. Generating Descriptions for Various Datasets:

# %%
evaluation_records = []

# %%
def generating_descriptions(topic, dataset_path):

    print(f"Read Dataset {topic}:")
    df = read_dataset(dataset_path)
    df_sample = df.head(5)
    sample_csv = df_sample.to_csv(index=False)
    print("==========================================================")
    print("Infer data profile:")
    dataprofile = infer_data_profile(df)
    print(dataprofile[0])
    print("==========================================================")
    print("Infer semantic profile:")
    semantic_profile = infer_semantic_profile(df)
    print(semantic_profile)
    print("==========================================================")
    print("Infer geo profile:")
    geo_profile = infer_geo_profile(semantic_profile, df_sample)
    print(geo_profile)
    print("==========================================================")
    print("Generated user focused AutoDDG description:")
    autoddg_desc = generate_dataset_description(sample_csv, dataprofile[0], True, semantic_profile, True, topic, True)
    print(autoddg_desc)
    print("==========================================================")
    print("Generated user focused description with Geo profile:")
    autoddg_geo_desc = generate_geoaware_description(sample_csv, dataprofile[0], True, semantic_profile, True, topic, True, geo_profile, True)
    print(autoddg_geo_desc)
    print("==========================================================")
    print("Generated search focused description with Geo description:")
    search_desc = generate_description_for_search(autoddg_geo_desc, topic)
    print(search_desc)
    print("==========================================================")
    evaluation_records.append({
        "topic": topic,
        "dataset_name": df,
        "data_profile": dataprofile[0],
        "semantic_profile": semantic_profile,
        "geo_profile": geo_profile,
        "baseline_description": autoddg_desc,
        "geo_description": autoddg_geo_desc,
        "search_description": search_desc
    })

# %% [markdown]
# ### Dataset 1: Parking Meters Locations and Status
# ##### https://data.cityofnewyork.us/Transportation/Parking-Meters-Locations-and-Status/693u-uax6/about_data

# %%
topic = "Parking Meters Locations and Status"
csv_path = "../examples/Parking_Meters_Locations_and_Status.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Parking Meters Locations and Status:
# (15582, 17)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **ObjectID**: Data is of type integer. There are 15582 unique values. Coverage spans from 0 to 15326.0.
# **Meter Number**: Data is of type integer. There are 15576 unique values. Coverage spans from 0 to 5043005.0.
# **Status**: Data is of type text. There are 3 unique values.
# **Pay By Cell Number**: Data is of type integer. There are 12092 unique values. Coverage spans from 0 to 509514.0.
# **Meter_Hours**: Data is of type text.
# **Parking_Facility_Name**: Data is of type text. There are 35 unique values.
# **Facility**: Data is of type text. There are 3 unique values.
# **Borough**: Data is of type text. There are 5 unique values.
# **On_Street**: Data is of type text. There are 1446 unique values.
# **Side_of_Street**: Data is of type text. There are 13 unique values.
# **From_Street**: Data is of type text. There are 2341 unique values.
# **To_Street**: Data is of type text. There are 2334 unique values.
# **Latitude**: Data is of type float. Coverage spans from 0 to 40.88751899863.
# **Longitude**: Data is of type float. Coverage spans from -74.02828691761 to 0.
# **X**: Data is of type text. There are 15566 unique values.
# **Y**: Data is of type text. There are 15568 unique values.
# **Location**: Data is of type geocoordinates.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **ObjectID**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier/key.
# **Meter Number**: Represents meter. Domain-specific type: utility. Function/Usage context: identifier.
# **Status**: Represents status. Domain-specific type: general. Function/Usage context: categorical feature.
# **Pay By Cell Number**: Represents identifier. Domain-specific type: financial. Function/Usage context: payment information.
# **Meter_Hours**: Represents time schedule. Contains temporal data (resolution: Hour). Domain-specific type: general. Function/Usage context: time constraint.
# **Parking_Facility_Name**: Represents facility name. Domain-specific type: urban planning/infrastructure. Function/Usage context: identifier.
# **Facility**: Represents location type. Domain-specific type: general. Function/Usage context: categorical.
# **Borough**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: demographic. Function/Usage context: aggregation key.
# **On_Street**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: geographic. Function/Usage context: identification.
# **Side_of_Street**: Represents direction. Contains spatial data (resolution: Directional). Domain-specific type: general. Function/Usage context: attribute.
# **From_Street**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: general. Function/Usage context: address component.
# **To_Street**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: general. Function/Usage context: address component.
# **Latitude**: Represents geographic location. Contains spatial data (resolution: Coordinates). Domain-specific type: geography. Function/Usage context: measurement.
# **Longitude**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: measurement.
# **X**: Represents numerical value. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: measurement.
# **Y**: Represents measurement. Domain-specific type: general. Function/Usage context: measurement.
# **Location**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: general. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='infrastructure', geometry_type='point', spatial_resolution='multi-level', spatial_use_cases=['accessibility mapping', 'navigation support', 'facility density analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains information about parking meters, including their unique object and meter numbers, status, and payment details via cell phone. It details the operating hours for each meter, specifying time constraints and schedules. The dataset also captures the precise location of each meter, including the parking facility name, borough, street name, side of the street, and cross-street information. Geographic coordinates such as latitude and longitude are provided for each meter, along with X and Y values and a detailed location point. This data is valuable for understanding parking regulations and spatial distribution within the city.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset represents parking meter locations and status, containing information about individual parking meters including their unique ObjectID and Meter Number. The Status column indicates whether a meter is Active, and Pay By Cell Number provides payment-related identifiers. Meter_Hours specifies the operational time schedule for parking. The dataset includes detailed spatial information, with Borough, On_Street, Side_of_Street, From_Street, and To_Street defining precise street locations. Latitude and Longitude coordinates, along with X and Y values, offer precise geographic measurements. The data's spatial role is infrastructure, with a point geometry type and multi-level spatial resolution, enabling accessibility mapping, navigation support, and facility density analysis. This dataset is valuable for urban planning and operational management, supporting applications such as optimizing parking enforcement routes, analyzing parking availability across different boroughs, and informing infrastructure development decisions related to parking facilities.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset represents parking meter locations and status, containing information about individual parking meters including their unique ObjectID and Meter Number. The Status column indicates whether a meter is Active, and Pay By Cell Number provides payment-related identifiers. Meter_Hours specifies the operational time schedule for parking. The dataset includes detailed spatial information, with Borough, On_Street, Side_of_Street, From_Street, and To_Street defining precise street locations. Latitude and Longitude coordinates, along with X and Y values, offer precise geographic measurements. The data's spatial role is infrastructure, with a point geometry type and multi-level spatial resolution, enabling accessibility mapping, navigation support, and facility density analysis. This dataset is valuable for urban planning and operational management, supporting applications such as optimizing parking enforcement routes, analyzing parking availability across different boroughs, and informing infrastructure development decisions related to parking facilities.
#
# Key Themes or Topics:
# - Urban Infrastructure Management
# - Transportation and Mobility
# - City Planning and Development
# - Public Space Management
# - Traffic and Congestion Control
#
# Applications and Use Cases:
# - Parking Enforcement Optimization
# - Parking Availability Analysis
# - Infrastructure Development Planning
# - Urban Mobility Studies
# - Geographic Information Systems (GIS) Analysis
# - Smart City Initiatives
# - Traffic Management Systems
# - Public Transportation Integration
# - Accessibility Mapping
# - Facility Density Analysis
#
# Concepts and Synonyms:
# - Parking Meters/Parking Meters Locations/Parking Meters Status/Parking Meter Data
# - Meter Number/Meter ID/Parking Meter Identifier
# - Meter Status/Meter Availability/Meter Operational Status/Active Meters/Inactive Meters
# - Pay By Cell/Mobile Payment/Phone Payment/App Payment/Digital Payment
# - Meter Hours/Operating Hours/Parking Schedule/Time Restrictions
# - Location/Spatial Data/Geographic Information/Coordinates
# - ObjectID/Unique Identifier/Record ID
# - Borough/District/Neighborhood/Area
# - On Street/Street Location/Roadway
# - Side of Street/Street Orientation
# - From Street/Starting Street/Street Segment Start
# - To Street/Ending Street/Street Segment End
# - Latitude/Y Coordinate/Northing
# - Longitude/X Coordinate/Easting
# - Infrastructure/Urban Infrastructure/Public Infrastructure
# - Point Geometry/Spatial Geometry/Geographic Features
# - Spatial Resolution/Granularity
# - Accessibility Mapping/Navigation Support
# - Facility Density/Parking Density/Meter Density
# - Urban Planning/City Planning/Municipal Planning
# - Operational Management/Asset Management/Resource Management
# - Parking Enforcement/Meter Enforcement/Parking Patrol
# - Parking Availability/Space Availability/Occupancy
# - Parking Facilities/Parking Infrastructure
#
# Keywords and Themes:
# - Parking Meters
# - Meter Locations
# - Meter Status
# - Pay By Cell
# - Meter Hours
# - ObjectID
# - Meter Number
# - Borough
# - On Street
# - Side of Street
# - From Street
# - To Street
# - Latitude
# - Longitude
# - X Coordinate
# - Y Coordinate
# - Infrastructure
# - Point Geometry
# - Spatial Data
# - Urban Planning
# - Operational Management
# - Parking Enforcement
# - Parking Availability
# - Accessibility
# - Navigation
# - Facility Density
# - Smart City
# - Transportation
# - Mobility
# - GIS
# - Public Space
#
# Additional Context:
# - This dataset provides granular spatial and operational data on parking meters, essential for understanding and managing urban parking infrastructure.
# - It can be integrated with other datasets such as traffic flow, public transit routes, or demographic data to conduct more comprehensive urban studies.
# - Supports the development of smart city solutions by providing real-time or near real-time information on parking infrastructure.
# - Crucial for optimizing resource allocation for parking enforcement and maintenance.
# - Enables analysis of parking equity and accessibility across different socio-economic areas within a city.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### Dataset 2: Community Parks Initiative Zone Boundaries
# ##### https://data.cityofnewyork.us/City-Government/Community-Parks-Initiative-Zone-Boundaries/vvdx-b56i

# %%
topic = "Community Parks Initiative Zone Boundaries"
csv_path = "../examples/CPI_Zones.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Community Parks Initiative Zone Boundaries:
# (55, 8)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **the_geom**: Data is of type text.
# **BoroCode**: Data is of type integer. There are 5 unique values. Coverage spans from 0 to 5.0.
# **BoroName**: Data is of type text. There are 5 unique values.
# **CountyFIPS**: Data is of type integer. There are 5 unique values. Coverage spans from 0 to 85.0.
# **NTACode**: Data is of type text. There are 55 unique values.
# **NTAName**: Data is of type text. There are 55 unique values.
# **Shape_Leng**: Data is of type text. There are 55 unique values.
# **Shape_Area**: Data is of type text. There are 55 unique values.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **the_geom**: Represents geographic feature. Contains spatial data (resolution: Coordinates). Domain-specific type: gis/mapping. Function/Usage context: spatial data representation.
# **BoroCode**: Represents geographic region code. Domain-specific type: urban planning/demographic. Function/Usage context: categorical identifier.
# **BoroName**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: demographic. Function/Usage context: aggregation key.
# **CountyFIPS**: Represents geographic entity. Contains spatial data (resolution: County). Domain-specific type: demographic. Function/Usage context: identifier.
# **NTACode**: Represents geographic area/neighborhood. Contains spatial data (resolution: Neighborhood or Community Level). Domain-specific type: demographic/urban planning. Function/Usage context: geographic identifier/categorization.
# **NTAName**: Represents location. Contains spatial data (resolution: Neighborhood). Domain-specific type: demographic. Function/Usage context: geographic identifier.
# **Shape_Leng**: Represents measurement. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: measurement.
# **Shape_Area**: Represents measurement. Domain-specific type: geographic information system. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='boundary', geometry_type='multi', spatial_resolution='multi-level', spatial_use_cases=['area-based aggregation', 'choropleth visualization', 'administrative-region analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains detailed geographic boundary information for New York City neighborhoods, specifically focusing on the NTA (Neighborhood Tabulation Area) level. Each record includes the geometric representation of the area, its borough code and name, county FIPS code, and the NTA code and name. Additionally, the dataset provides measurements for the length and area of each shape, which are valuable for spatial analysis and urban planning. The data is organized by borough and neighborhood, offering a granular view of the city's geography.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset represents the boundary polygons for Community Parks Initiative Zones. It contains detailed spatial information for these zones, including their geographic boundaries, identified by `the_geom` which holds multi-geometry data at a multi-level spatial resolution. The dataset is structured to support area-based aggregation, choropleth visualization, and administrative-region analysis. Key identifiers include `BoroCode`, `BoroName`, `CountyFIPS`, `NTACode`, and `NTAName`, which categorize these zones by borough and neighborhood. Measurements such as `Shape_Leng` and `Shape_Area` provide geometric properties for each zone. This data is valuable for urban planning and demographic analysis, enabling applications such as identifying park accessibility within specific neighborhoods or analyzing the spatial distribution of park initiatives across different boroughs.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset represents the boundary polygons for Community Parks Initiative Zone Boundaries. It contains detailed spatial information for these zones, including their geographic boundaries, identified by `the_geom` which holds multi-geometry data at a multi-level spatial resolution. The dataset is structured to support area-based aggregation, choropleth visualization, and administrative-region analysis. Key identifiers include `BoroCode`, `BoroName`, `CountyFIPS`, `NTACode`, and `NTAName`, which categorize these zones by borough and neighborhood. Measurements such as `Shape_Leng` and `Shape_Area` provide geometric properties for each zone. This data is valuable for urban planning and demographic analysis, enabling applications such as identifying park accessibility within specific neighborhoods or analyzing the spatial distribution of park initiatives across different boroughs.
#
# Key Themes or Topics:
# - Urban Planning/Community Development
# - Public Parks and Green Space Management
# - Geospatial Data Analysis/Spatial Analysis
# - Municipal Services and Initiatives
# - Neighborhood Boundaries/Administrative Divisions
# - Environmental Justice/Equitable Access to Resources
#
# Applications and Use Cases:
# - Park Planning and Development
# - Urban Redevelopment Analysis
# - Community Needs Assessment
# - Policy Impact Evaluation
# - Geospatial Visualization and Mapping
# - Accessibility Studies (e.g., park access, service access)
# - Demographic Profiling by Zone
# - Equitable Distribution Analysis of Public Resources
# - Land Use Planning
# - Infrastructure Planning
# - Public Health Initiatives Spatial Analysis
#
# Concepts and Synonyms:
# - Community Parks Initiative Zone Boundaries/CPI Zones/Park Initiative Zones/Parks Zones
# - Geographic Boundaries/Spatial Boundaries/Zone Polygons/Area Boundaries
# - Spatial Data/Geospatial Information/Geographic Information
# - Multi-geometry Data/Multi-level Resolution
# - Area-based Aggregation/Spatial Aggregation
# - Choropleth Visualization/Thematic Mapping
# - Administrative Region Analysis/Borough Analysis/Neighborhood Analysis
# - Borough Code/Boro Code/Borough Name/Boro Name
# - County FIPS/FIPS Code
# - NTA Code/Neighborhood Tabulation Area Code
# - NTA Name/Neighborhood Tabulation Area Name
# - Geometric Properties/Shape Length/Shape Area
# - Urban Planning/City Planning/Municipal Planning
# - Demographic Analysis/Population Analysis
# - Park Accessibility/Green Space Access
# - Spatial Distribution/Geographic Distribution
# - Public Parks/Community Parks/Green Spaces/Parks
# - Initiative Zones/Program Zones/Designated Areas
# - Boundary Polygons/Zone Geometries
# - Spatial Resolution/Geographic Detail
# - Public Space Management
# - Neighborhood Services
# - Local Government Initiatives
# - City Services
# - Community Infrastructure
# - Redevelopment Projects
# - Social Equity Analysis
# - Resource Allocation
#
# Keywords and Themes:
# - Community Parks Initiative
# - Zone Boundaries
# - Park Zones
# - Geospatial
# - Spatial Data
# - Polygons
# - Urban Planning
# - Community Development
# - Green Space
# - Public Parks
# - Administrative Boundaries
# - Borough
# - Neighborhood
# - NTA
# - FIPS
# - Geometry
# - Area
# - Length
# - Visualization
# - Analysis
# - Planning
# - Development
# - Accessibility
# - Distribution
# - Municipal
# - Initiative
# - Public Services
# - Urban
# - City
# - Local
# - Equity
# - Demographics
#
# Additional Context:
# - This dataset is crucial for understanding the spatial footprint and intended coverage of the Community Parks Initiative, particularly for assessing its reach and impact at the borough and neighborhood (NTA) levels. It supports data-driven decision-making in urban planning, resource allocation, and policy development aimed at enhancing community well-being through park access and development. The inclusion of detailed geometric and administrative identifiers allows for robust spatial queries and comparative analyses across different urban areas. The data can be integrated with demographic, socio-economic, and public health datasets to conduct comprehensive studies on environmental justice and equitable access to recreational facilities.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### Dataset 3: Landmarks Complaints
# ##### https://data.cityofnewyork.us/Housing-Development/Landmarks-Complaints/ck4n-5h6x/about_data

# %%
topic = "Landmark Complaints"
csv_path = "../examples/Landmarks_Complaints.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Landmark Complaints:
# (6689, 18)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **Complaint #**: Data is of type text. There are 6686 unique values.
# **Date**: Data is of type text. There are 2727 unique values.
# **Address #**: Data is of type text. There are 1646 unique values.
# **Street Name**: Data is of type text. There are 1382 unique values.
# **Borough**: Data is of type text. There are 11 unique values.
# **Block**: Data is of type integer. There are 1338 unique values. Coverage spans from 0 to 2476.0.
# **Lot**: Data is of type integer. There are 243 unique values. Coverage spans from 0 to 93.0.
# **BIN**: Data is of type integer. There are 4790 unique values. Coverage spans from 0 to 5015074.0.
# **Postcode**: Data is of type integer. There are 149 unique values. Coverage spans from 0 to 11377.0.
# **Landmark Name**: Data is of type text.
# **Work Reported**: Data is of type text.
# **Action Taken**: Data is of type text. There are 3 unique values.
# **Status**: Data is of type text. There are 2 unique values.
# **Council District**: Data is of type integer. There are 50 unique values. Coverage spans from 0 to 47.0.
# **Community Board**: Data is of type text. There are 79 unique values.
# **NTA**: Data is of type text. There are 120 unique values.
# **Latitude**: Data is of type float. Coverage spans from 0 to 40.85158633446.
# **Longitude**: Data is of type float. Coverage spans from -74.00983034663 to 0.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **Complaint #**: Represents complaint identifier. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: customer service. Function/Usage context: identifier.
# **Date**: Represents temporal entity. Contains temporal data (resolution: Day). Domain-specific type: general. Function/Usage context: aggregation key.
# **Address #**: Represents location identifier. Domain-specific type: general. Function/Usage context: identifier.
# **Street Name**: Represents location. Contains spatial data (resolution: Street). Domain-specific type: geographic. Function/Usage context: location identifier.
# **Borough**: Represents location. Contains spatial data (resolution: City). Domain-specific type: demographic. Function/Usage context: aggregation key.
# **Block**: Represents general. Domain-specific type: general. Function/Usage context: measurement.
# **Lot**: Represents identifier. Domain-specific type: inventory management. Function/Usage context: identification/categorization.
# **BIN**: Represents identifier. Domain-specific type: financial. Function/Usage context: identifier.
# **Postcode**: Represents location. Contains spatial data (resolution: Postal Code). Domain-specific type: demographic. Function/Usage context: geographic identifier.
# **Landmark Name**: Represents location. Contains temporal data (resolution: ). Contains spatial data (resolution: Landmark). Domain-specific type: cultural heritage. Function/Usage context: identifier.
# **Work Reported**: Represents work/task description. Domain-specific type: construction/permitting. Function/Usage context: descriptive information.
# **Action Taken**: Represents action/outcome. Domain-specific type: regulatory/compliance. Function/Usage context: categorical data/status.
# **Status**: Represents status. Domain-specific type: general. Function/Usage context: categorical feature.
# **Council District**: Represents geographical/administrative unit. Domain-specific type: government/civic. Function/Usage context: categorization/grouping.
# **Community Board**: Represents location. Contains spatial data (resolution: Neighborhood/Borough). Domain-specific type: demographic. Function/Usage context: identifier.
# **NTA**: Represents location. Contains spatial data (resolution: Neighborhood). Domain-specific type: urban planning. Function/Usage context: geographic identifier.
# **Latitude**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: measurement.
# **Longitude**: Represents location entity. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='event', geometry_type='point', spatial_resolution='multi-level', spatial_use_cases=['spatio-temporal incident analysis', 'hotspot mapping', 'event clustering', 'trend analysis over time'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains records of building complaints, including the complaint number, date, address, borough, block, lot, building identification number (BIN), postcode, and landmark name. It also details the work reported, action taken, and the status of the complaint. Geographic information is provided through council district, community board, NTA (neighborhood tabulation area), latitude, and longitude. The dataset captures complaints related to construction and permitting work, with actions taken often involving warning letters. This data can be used for analyzing building code violations and their resolution within specific New York City neighborhoods and historic districts.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset contains records of landmark complaints, detailing specific incidents reported on various dates. Each complaint is identified by a unique complaint number and is associated with a precise address, including street name, address number, postcode, and geographical coordinates (latitude and longitude). The data captures the borough, council district, community board, and NTA for each complaint, providing multi-level spatial resolution. Complaints are categorized by the work reported, such as construction or painting, and include information on the action taken and the final status of the complaint. The dataset's geospatial role as an event with point geometry enables spatio-temporal incident analysis, hotspot mapping, and event clustering. This information is valuable for analyzing trends in landmark complaints over time and for operational planning related to historic districts and urban development.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# This dataset contains records of landmark complaints, detailing specific incidents reported on various dates. Each complaint is identified by a unique complaint number and is associated with a precise address, including street name, address number, postcode, and geographical coordinates (latitude and longitude). The data captures the borough, council district, community board, and NTA for each complaint, providing multi-level spatial resolution. Complaints are categorized by the work reported, such as construction or painting, and include information on the action taken and the final status of the complaint. The dataset's geospatial role as an event with point geometry enables spatio-temporal incident analysis, hotspot mapping, and event clustering. This information is valuable for analyzing trends in landmark complaints over time and for operational planning related to historic districts and urban development.
#
# Key Themes or Topics:
# - Historic Preservation/Landmark Protection
# - Urban Development and Planning
# - Building and Construction Enforcement
# - Municipal Services and Complaints
# - Public Works and Infrastructure Management
# - Heritage Site Management
# - Property and Land Use Regulation
#
# Applications and Use Cases:
# - Historic district management and preservation planning
# - Urban planning and zoning analysis
# - Enforcement of building codes and regulations
# - Spatio-temporal analysis of urban incidents and complaints
# - Hotspot mapping of landmark-related issues
# - Event clustering for resource allocation
# - Operational planning for historic site maintenance and development
# - Policy formulation for heritage conservation
# - Statistical modeling of complaint trends
# - Public engagement and awareness regarding landmark protection
#
# Concepts and Synonyms:
# - Landmark Complaints/Historic Landmark Complaints/Heritage Site Complaints/Building Complaints/Property Complaints
# - Historic Preservation/Landmark Preservation/Heritage Conservation/Building Conservation/Historic Site Protection
# - Urban Development/City Development/Community Development/Land Development/Urban Planning/City Planning
# - Construction Work/Building Work/Renovation Work/Demolition Work/Alteration Work
# - Painting Work/Facade Work/Exterior Work
# - Action Taken/Resolution/Enforcement Action/Remedial Action
# - Complaint Status/Case Status/Resolution Status/Complaint Outcome
# - Geospatial Analysis/Spatial Analysis/Location-Based Analysis/Geographic Information Systems (GIS)
# - Event Data/Incident Data/Complaint Records/Reported Incidents
# - Point Geometry/Spatial Events
# - Spatio-temporal Analysis/Temporal Analysis/Incident Tracking
# - Hotspot Mapping/Density Analysis/Clustering
# - Borough/District/Community Board/Neighborhood Tabulation Area (NTA)
# - Address/Street Name/Address Number/Postcode/Zip Code
# - Latitude/Longitude/Geographical Coordinates
# - Municipal Enforcement/Regulatory Compliance/Code Enforcement
# - Historic Districts/Heritage Areas/Conservation Zones
# - Urban Renewal/City Revitalization
#
# Keywords and Themes:
# - Landmark
# - Complaint
# - Historic Preservation
# - Urban Planning
# - Construction
# - Painting
# - Enforcement
# - Status
# - Address
# - Postcode
# - Latitude
# - Longitude
# - Borough
# - Council District
# - Community Board
# - NTA
# - Geospatial
# - Spatio-temporal
# - Hotspot
# - Clustering
# - Event
# - Incident
# - Heritage
# - Building
# - Regulation
# - Development
# - Conservation
# - Municipality
# - Report
# - Date
# - Work
#
# Additional Context:
# - This dataset is crucial for understanding the dynamics of managing and protecting historic landmarks within an urban environment.
# - It provides valuable data for identifying areas with high complaint activity related to landmarks, informing targeted enforcement and outreach efforts.
# - The spatial and temporal attributes enable sophisticated analysis of how landmark-related issues manifest and evolve over time and across different geographical areas.
# - Integration with other urban datasets (e.g., zoning maps, building permits, demographic data) could provide deeper insights into the drivers of landmark complaints.
# - Useful for researchers studying urban heritage, community engagement, and regulatory effectiveness.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### Dataset 4: Centerline
# ##### https://data.cityofnewyork.us/City-Government/Centerline/3mf9-qshr

# %%
topic = "Centerline"
csv_path = "../examples/Centerline.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Centerline:
# (122050, 64)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **the_geom**: Data is of type text.
# **PHYSICALID**: Data is of type text. There are 122008 unique values.
# **L_LOW_HN**: Data is of type text. There are 7569 unique values.
# **L_HIGH_HN**: Data is of type text. There are 7958 unique values.
# **R_LOW_HN**: Data is of type text. There are 7676 unique values.
# **R_HIGH_HN**: Data is of type text. There are 8004 unique values.
# **L_ZIP**: Data is of type integer. There are 215 unique values. Coverage spans from 0 to 11436.0.
# **R_ZIP**: Data is of type integer. There are 223 unique values. Coverage spans from 0 to 11436.0.
# **STATUS**: Data is of type integer. There are 3 unique values. Coverage spans from 0 to 2.0.
# **BIKE_LANE**: Data is of type integer. There are 10 unique values. Coverage spans from 0 to 3.0.
# **TRAFDIR**: Data is of type text. There are 4 unique values.
# **RW_TYPE**: Data is of type integer. There are 13 unique values. Coverage spans from 0 to 2.0.
# **PRE_TYPE**: Data is of type text. There are 7 unique values.
# **POST_TYPE**: Data is of type text. There are 70 unique values.
# **OBJECTID**: Data is of type text. There are 122050 unique values.
# **FCC**: Data is of type integer. There are 1 unique values. Coverage spans from 0 to 10.0.
# **Left side Block Face ID**: Data is of type text. There are 81927 unique values.
# **Right Side Block Face ID**: Data is of type text. There are 81694 unique values.
# **Average Travel Time**: Data is of type missingdata.
# **Roadway Jurisdiction**: Data is of type integer. There are 2 unique values. Coverage spans from 0 to 3.0.
# **NOMINALDIR**: Data is of type missingdata.
# **ACCESSIBLE**: Data is of type integer. There are 4 unique values. Coverage spans from 0 to 3.0.
# **NONPED**: Data is of type text. There are 2 unique values.
# **Borough Code**: Data is of type integer. There are 5 unique values. Coverage spans from 0 to 5.0.
# **Borough Indicator**: Data is of type integer. There are 2 unique values. Coverage spans from 0 to 2.0.
# **Segloc Status**: Data is of type text. There are 5 unique values.
# **San District Inc**: Data is of type integer. There are 2 unique values. Coverage spans from 0 to 2.0.
# **Left Side Subset**: Data is of type text. There are 63 unique values.
# **Right Side Subset**: Data is of type text. There are 60 unique values.
# **Continuous Parity Flag**: Data is of type integer. There are 2 unique values. Coverage spans from 0 to 2.0.
# **Twisted Parity Flag**: Data is of type text. There are 2 unique values.
# **Posted Speed**: Data is of type integer. There are 8 unique values. Coverage spans from 0 to 25.0.
# **Segment Length**: Data is of type float. Coverage spans from 0 to 899.8331336.
# **Street Width**: Data is of type integer. There are 84 unique values. Coverage spans from 0 to 70.0.
# **Street Width IRR**: Data is of type missingdata.
# **Special Disaster**: Data is of type missingdata.
# **Fire Lane**: Data is of type missingdata.
# **CREATED_DATE**: Data is of type text.
# **MODIFIED_DATE**: Data is of type text.
# **WITHIN_BNDY_DIST**: Data is of type integer. There are 2 unique values. Coverage spans from 0 to 4.0.
# **TRUCK ROUTE TYPE**: Data is of type integer. There are 3 unique values. Coverage spans from 0 to 3.0.
# **Collection Method**: Data is of type text. There are 1 unique values.
# **FROM_LEVEL_CODE**: Data is of type integer. There are 19 unique values. Coverage spans from 0 to 13.0.
# **TO_LEVEL_CODE**: Data is of type integer. There are 19 unique values. Coverage spans from 0 to 13.0.
# **B5SC**: Data is of type integer. There are 11383 unique values. Coverage spans from 0 to 555320.0.
# **Snow Priority**: Data is of type text. There are 4 unique values.
# **JOINID**: Data is of type missingdata.
# **BPHYS_ID**: Data is of type missingdata.
# **Cartography Display Level**: Data is of type integer. There are 3 unique values. Coverage spans from 0 to 30.0.
# **Number Travel Lanes**: Data is of type integer. There are 11 unique values. Coverage spans from 0 to 4.0.
# **Number Park Lanes**: Data is of type integer. There are 4 unique values. Coverage spans from 0 to 2.0.
# **Number Total Lane**: Data is of type integer. There are 11 unique values. Coverage spans from 0 to 6.0.
# **Pre-Modifier**: Data is of type text. There are 2 unique values.
# **Pre-Directional**: Data is of type text. There are 4 unique values.
# **Post Directional**: Data is of type text. There are 5 unique values.
# **Post Modifier**: Data is of type text. There are 27 unique values.
# **Full Street Name**: Data is of type text. There are 10612 unique values.
# **BIKE TRAFFIC DIRECTION**: Data is of type text. There are 3 unique values.
# **SHAPE__Length**: Data is of type float. Coverage spans from 0 to 514.53692102981.
# **GlobalID**: Data is of type text. There are 122050 unique values.
# **SEGMENT_TYPE**: Data is of type missingdata.
# **SEGMENT_TYPE_VALUE**: Data is of type missingdata.
# **STREET NAME**: Data is of type text. There are 7008 unique values.
# **Street Name Label**: Data is of type text. There are 10622 unique values.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **the_geom**: Represents geographic feature. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial data. Function/Usage context: data representation.
# **PHYSICALID**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **L_LOW_HN**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **L_HIGH_HN**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **R_LOW_HN**: Represents identifier. Domain-specific type: healthcare. Function/Usage context: measurement.
# **R_HIGH_HN**: Represents identifier. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: identifier.
# **L_ZIP**: Represents location. Contains spatial data (resolution: Zip Code). Domain-specific type: geographic. Function/Usage context: identifier.
# **R_ZIP**: Represents location. Contains spatial data (resolution: Zip Code). Domain-specific type: general. Function/Usage context: aggregation key.
# **STATUS**: Represents status code. Domain-specific type: general. Function/Usage context: categorical indicator.
# **BIKE_LANE**: Represents infrastructure. Domain-specific type: urban planning.
# **TRAFDIR**: Represents direction indicator. Domain-specific type: traffic/transportation. Function/Usage context: categorical feature.
# **RW_TYPE**: Represents categorical/identifier. Domain-specific type: general. Function/Usage context: categorization/grouping.
# **PRE_TYPE**: Represents categorical. Domain-specific type: general. Function/Usage context: categorization/classification.
# **POST_TYPE**: Represents location suffix. Domain-specific type: geographic. Function/Usage context: categorical value.
# **OBJECTID**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **FCC**: Represents identifier. Domain-specific type: telecommunications. Function/Usage context: identifier.
# **Left side Block Face ID**: Represents identifier. Domain-specific type: urban planning/gis. Function/Usage context: identifier.
# **Right Side Block Face ID**: Represents identifier. Domain-specific type: general. Function/Usage context: aggregation key.
# **Average Travel Time**: Represents measurement. Domain-specific type: transportation. Function/Usage context: measurement.
# **Roadway Jurisdiction**: Represents jurisdiction. Domain-specific type: government/civic. Function/Usage context: categorization.
# **NOMINALDIR**: Domain-specific type: general.
# **ACCESSIBLE**: Represents attribute. Domain-specific type: general. Function/Usage context: descriptive feature.
# **NONPED**: Domain-specific type: general.
# **Borough Code**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: demographic. Function/Usage context: identifier.
# **Borough Indicator**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: demographic. Function/Usage context: categorical identifier.
# **Segloc Status**: Represents status. Domain-specific type: general. Function/Usage context: measurement.
# **San District Inc**: Represents location. Domain-specific type: general. Function/Usage context: identifier.
# **Left Side Subset**: Represents categorical code. Domain-specific type: general. Function/Usage context: categorical identifier.
# **Right Side Subset**: Represents categorical identifier. Domain-specific type: general. Function/Usage context: categorization/grouping.
# **Continuous Parity Flag**: Represents flag/indicator. Domain-specific type: general. Function/Usage context: measurement.
# **Twisted Parity Flag**: Represents flag. Domain-specific type: general. Function/Usage context: categorical indicator.
# **Posted Speed**: Represents speed measurement. Domain-specific type: transportation. Function/Usage context: measurement.
# **Segment Length**: Represents measurement. Domain-specific type: general. Function/Usage context: measurement.
# **Street Width**: Represents physical feature. Contains spatial data (resolution: Street Segment). Domain-specific type: urban planning/infrastructure. Function/Usage context: measurement.
# **Street Width IRR**: Represents measurement. Domain-specific type: urban planning. Function/Usage context: measurement.
# **Special Disaster**: Represents event. Domain-specific type: general. Function/Usage context: descriptive.
# **Fire Lane**: Represents n/a. Domain-specific type: n/a. Function/Usage context: n/a.
# **CREATED_DATE**: Represents temporal entity. Contains temporal data (resolution: Timestamp). Domain-specific type: general. Function/Usage context: measurement.
# **MODIFIED_DATE**: Represents temporal entity. Contains temporal data (resolution: Timestamp). Domain-specific type: general. Function/Usage context: measurement.
# **WITHIN_BNDY_DIST**: Represents general. Domain-specific type: general. Function/Usage context: measurement.
# **TRUCK ROUTE TYPE**: Represents route type. Domain-specific type: logistics. Function/Usage context: categorization.
# **Collection Method**: Represents collection method. Domain-specific type: general. Function/Usage context: measurement.
# **FROM_LEVEL_CODE**: Represents code. Domain-specific type: general. Function/Usage context: identifier.
# **TO_LEVEL_CODE**: Represents code. Domain-specific type: general. Function/Usage context: identifier.
# **B5SC**: Represents numerical identifier. Domain-specific type: general. Function/Usage context: identifier.
# **Snow Priority**: Represents status/category. Domain-specific type: climate/weather. Function/Usage context: categorization/grouping.
# **JOINID**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **BPHYS_ID**: Represents identifier. Function/Usage context: identifier.
# **Cartography Display Level**: Represents measurement. Domain-specific type: cartography. Function/Usage context: measurement.
# **Number Travel Lanes**: Represents roadway feature. Domain-specific type: transportation. Function/Usage context: measurement.
# **Number Park Lanes**: Represents facility feature. Domain-specific type: leisure/entertainment. Function/Usage context: measurement.
# **Number Total Lane**: Represents infrastructure feature. Domain-specific type: transportation. Function/Usage context: measurement.
# **Pre-Modifier**: Represents descriptive term. Domain-specific type: general. Function/Usage context: descriptive attribute.
# **Pre-Directional**: Domain-specific type: general.
# **Post Directional**: Domain-specific type: general. Function/Usage context: measurement.
# **Post Modifier**: Represents other. Domain-specific type: general. Function/Usage context: data quality/missing value indicator.
# **Full Street Name**: Represents location. Contains spatial data (resolution: Street). Domain-specific type: geographic. Function/Usage context: descriptive.
# **BIKE TRAFFIC DIRECTION**: Represents traffic data. Domain-specific type: transportation. Function/Usage context: measurement.
# **SHAPE__Length**: Represents measurement. Domain-specific type: geospatial. Function/Usage context: measurement.
# **GlobalID**: Represents unique identifier. Domain-specific type: general. Function/Usage context: identifier.
# **SEGMENT_TYPE**: Represents categorical. Domain-specific type: general. Function/Usage context: categorization/grouping.
# **SEGMENT_TYPE_VALUE**: Represents categorical/segment information. Domain-specific type: general. Function/Usage context: categorization/classification.
# **STREET NAME**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: general. Function/Usage context: identifier.
# **Street Name Label**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: address. Function/Usage context: identification.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='infrastructure', geometry_type='multi', spatial_resolution='multi-level', spatial_use_cases=['accessibility mapping', 'navigation support', 'facility density analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains detailed information about road segments, including their geometric representation, physical identifiers, and various attributes related to their location, status, and characteristics. It captures data such as street names, zip codes, borough information, and specific details like the presence of bike lanes, traffic direction, and roadway type. The dataset also includes measurements like segment length, street width, and average travel time, along with temporal information such as creation and modification dates. Furthermore, it provides insights into traffic management aspects like posted speed limits, snow priority, and truck route types, offering a comprehensive view of urban infrastructure and transportation features.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset represents road centerlines, providing detailed geospatial information about street segments. It contains multi-level spatial data, enabling use cases such as accessibility mapping, navigation support, and facility density analysis. Key attributes include unique identifiers like PHYSICALID and GlobalID, along with spatial data such as the_geom representing geographic features and SHAPE__Length for segment measurements. The dataset also captures various road characteristics, including street width, posted speed, and the number of travel, park, and total lanes. Information on traffic direction, bike lanes, and truck route types is also present. Temporal data is available through CREATED_DATE and MODIFIED_DATE fields. The dataset's structure includes categorical identifiers for location, such as L_ZIP, R_ZIP, and Borough Code, and descriptive attributes like Full Street Name and STREET NAME. This data is valuable for urban planning, transportation analysis, and infrastructure management.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset represents road centerlines, providing detailed geospatial information about street segments. It contains multi-level spatial data, enabling use cases such as accessibility mapping, navigation support, and facility density analysis. Key attributes include unique identifiers like PHYSICALID and GlobalID, along with spatial data such as the_geom representing geographic features and SHAPE__Length for segment measurements. The dataset also captures various road characteristics, including street width, posted speed, and the number of travel, park, and total lanes. Information on traffic direction, bike lanes, and truck route types is also present. Temporal data is available through CREATED_DATE and MODIFIED_DATE fields. The dataset's structure includes categorical identifiers for location, such as L_ZIP, R_ZIP, and Borough Code, and descriptive attributes like Full Street Name and STREET NAME. This data is valuable for urban planning, transportation analysis, and infrastructure management.
#
# Key Themes or Topics:
# - Transportation Networks/Infrastructure
# - Geospatial Data/Mapping
# - Urban Planning/Development
# - Roadway Characteristics
# - Navigation and Routing
# - Spatial Analysis
#
# Applications and Use Cases:
# - Accessibility Mapping/Analysis
# - Navigation System Development
# - Facility Density Studies
# - Transportation Planning
# - Infrastructure Management
# - Urban Design
# - Traffic Flow Analysis
# - Route Optimization
# - Geographic Information Systems (GIS) Applications
# - Asset Management
#
# Concepts and Synonyms:
# - Centerline/Road Centerline/Street Centerline
# - Road Network/Street Network/Transportation Network
# - Geospatial Data/Geographic Data/Spatial Data
# - Geometry/Geographic Features/Spatial Features
# - Road Segment/Street Segment
# - Road Width/Street Width
# - Posted Speed/Speed Limit
# - Travel Lanes/Number of Lanes
# - Park Lanes/Parking Lanes
# - Total Lanes
# - Traffic Direction/Direction of Travel
# - Bike Lane/Bicycle Lane
# - Truck Route/Commercial Vehicle Route
# - Temporal Data/Date Information
# - Creation Date/Modification Date
# - Location Identifiers/Geographic Identifiers
# - ZIP Code/L_ZIP/R_ZIP
# - Borough Code
# - Street Name/Full Street Name
# - Physical Identifier/PHYSICALID
# - Global Identifier/GlobalID
# - Shape Length/SHAPE__Length
# - Geographic Information System (GIS)/GIS Data
# - Spatial Analysis/Geospatial Analysis
# - Urban Mobility
# - Road Infrastructure
# - Transportation Engineering
# - Cadastral Data (related for context)
#
# Keywords and Themes:
# - Centerline
# - Road
# - Street
# - Geospatial
# - Spatial
# - Geometry
# - Network
# - Transportation
# - Infrastructure
# - Urban
# - Planning
# - Navigation
# - Routing
# - Speed
# - Lane
# - Bike
# - Truck
# - GIS
# - Mapping
# - Analysis
# - Measurement
# - Identifier
# - Date
# - Location
# - Name
#
# Additional Context:
# - This dataset is crucial for understanding the physical structure of urban and suburban road systems. Its detailed attributes allow for granular analysis of road characteristics at a segment level. The inclusion of both spatial geometry and descriptive attributes makes it highly valuable for integrating with other datasets for comprehensive studies, such as combining with demographic data for accessibility analysis or with traffic volume data for network performance evaluation. It supports applications requiring precise location and road feature information.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### Dataset 5: Parks Zones
# ##### https://data.cityofnewyork.us/City-Government/Parks-Zones/4j29-i5ry/about_data

# %%
topic = "Parks Zones"
csv_path = "../examples/Parks_Zones.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Parks Zones:
# (928, 20)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **ACRES**: Data is of type float. Coverage spans from 0 to 79.02298176.
# **BOROUGH**: Data is of type text. There are 5 unique values.
# **COMMUNITYBOARD**: Data is of type text. There are 84 unique values.
# **COUNCILDISTRICT**: Data is of type integer. There are 51 unique values. Coverage spans from 0 to 51.0.
# **DEPARTMENT**: Data is of type text. There are 70 unique values.
# **DESCRIPTION**: Data is of type text.
# **GISPROPNUM**: Data is of type text. There are 203 unique values.
# **LOCATION**: Data is of type text.
# **NYS_ASSEMBLY**: Data is of type text. There are 100 unique values.
# **NYS_SENATE**: Data is of type text. There are 47 unique values.
# **OMPPROPID**: Data is of type text. There are 928 unique values.
# **PRECINCT**: Data is of type integer. There are 77 unique values. Coverage spans from 0 to 123.0.
# **PROPNAME**: Data is of type text. There are 188 unique values.
# **RETIRED**: Data is of type text. There are 1 unique values.
# **RETIREDDATE**: Data is of type missingdata.
# **SITENAME**: Data is of type missingdata.
# **SUBCATEGORY**: Data is of type missingdata.
# **US_CONGRESS**: Data is of type text. There are 26 unique values.
# **ZIPCODE**: Data is of type text. There are 169 unique values.
# **multipolygon**: Data is of type text.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **ACRES**: Represents area/size. Domain-specific type: real estate/land management. Function/Usage context: measurement.
# **BOROUGH**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: geographic. Function/Usage context: categorical identifier.
# **COMMUNITYBOARD**: Represents community board identifier. Domain-specific type: demographic. Function/Usage context: identifier.
# **COUNCILDISTRICT**: Represents geographic division. Domain-specific type: governmental/civic. Function/Usage context: categorical identifier.
# **DEPARTMENT**: Represents department. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: categorical identifier.
# **DESCRIPTION**: Represents location. Contains spatial data (resolution: Park, Playground, Zone). Domain-specific type: urban planning, recreation. Function/Usage context: descriptive identifier.
# **GISPROPNUM**: Represents identifier. Domain-specific type: real estate. Function/Usage context: categorization.
# **LOCATION**: Represents location. Contains spatial data (resolution: Street/Area). Domain-specific type: general. Function/Usage context: descriptive information.
# **NYS_ASSEMBLY**: Represents geopolitical entity identifier. Domain-specific type: political/governmental. Function/Usage context: identifier.
# **NYS_SENATE**: Represents political district/identifier. Domain-specific type: government/political. Function/Usage context: identifier/category.
# **OMPPROPID**: Represents identifier. Domain-specific type: real estate. Function/Usage context: unique identifier.
# **PRECINCT**: Represents location. Contains spatial data (resolution: Precinct). Domain-specific type: administrative/electoral. Function/Usage context: identifier.
# **PROPNAME**: Represents location. Contains spatial data (resolution: Park Name). Domain-specific type: general. Function/Usage context: geographic identifier.
# **RETIRED**: Represents status. Domain-specific type: general. Function/Usage context: indicator.
# **RETIREDDATE**: Represents temporal entity. Contains temporal data (resolution: Date). Domain-specific type: general. Function/Usage context: attribute.
# **SITENAME**: Represents location. Domain-specific type: general. Function/Usage context: identifier.
# **SUBCATEGORY**: Represents general. Domain-specific type: general. Function/Usage context: aggregation key.
# **US_CONGRESS**: Represents political entity. Domain-specific type: government/politics. Function/Usage context: identifier.
# **ZIPCODE**: Represents location. Contains spatial data (resolution: Zip Code). Domain-specific type: geographic. Function/Usage context: identifier.
# **multipolygon**: Represents polygon. Contains temporal data (resolution: ). Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: geographical boundary.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='boundary', geometry_type='multi', spatial_resolution='multi-level', spatial_use_cases=['area-based aggregation', 'choropleth visualization', 'administrative-region analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains information about various parks and recreational areas, including their size in acres, borough, community board, council district, and department. It also provides a detailed description of the location, including specific streets or areas, and relevant political and administrative identifiers such as New York State Assembly and Senate districts, precinct, and US Congressional district. The dataset includes property numbers and unique property identifiers, along with the park's name and whether it has been retired, with a retirement date if applicable. The geospatial data is provided in the form of multipolygons, outlining the geographical boundaries of these locations.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset contains information about parks and their zones, providing details on their size in acres, borough, community board, council district, department, and a descriptive location. It includes identifiers such as GIS property number, precinct, and OMP property ID, along with state assembly and senate district information, and zip codes. The dataset's spatial role is boundary, with a multi-level geometry type that supports area-based aggregation and administrative-region analysis. The multipolygon column defines the geographical boundaries for each park zone. This data is useful for analyzing parkland distribution across different administrative divisions, planning park maintenance and development based on area and location, and understanding the spatial extent of recreational zones within parks.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset contains information about parks and their zones, providing details on their size in acres, borough, community board, council district, department, and a descriptive location. It includes identifiers such as GIS property number, precinct, and OMP property ID, along with state assembly and senate district information, and zip codes. The dataset's spatial role is boundary, with a multi-level geometry type that supports area-based aggregation and administrative-region analysis. The multipolygon column defines the geographical boundaries for each park zone. This data is useful for analyzing parkland distribution across different administrative divisions, planning park maintenance and development based on area and location, and understanding the spatial extent of recreational zones within parks.
#
# Key Themes or Topics:
# - Parks and Recreation Management/Urban Green Spaces
# - Municipal Parks/Public Parks
# - Park Zones and Boundaries/Parkland Delineation
# - Land Use and Zoning/Recreational Land
# - Geographic Information Systems (GIS)/Spatial Data Analysis
# - Urban Planning and Development/Community Development
# - Environmental Management/Conservation Areas
#
# Applications and Use Cases:
# - Park Land Distribution Analysis/Green Space Equity Assessment
# - Park Maintenance and Development Planning/Resource Allocation
# - Spatial Extent Analysis of Recreational Zones/Park Usage Pattern Identification
# - Administrative Region Analysis of Park Services/Borough-level Park Planning
# - GIS Mapping and Spatial Visualization of Park Assets/Urban Green Infrastructure Mapping
# - Policy Formulation for Parks and Open Space/Recreational Facility Planning
# - Environmental Impact Assessment related to Park Development/Biodiversity Conservation Planning
#
# Concepts and Synonyms:
# - Parks/Parklands/Green Spaces/Open Spaces/Recreational Areas/Public Gardens
# - Zones/Sections/Areas/Districts/Divisions/Territories
# - Boundaries/Perimeters/Limits/Fences/Demarcations
# - Size/Area/Acreage/Extent/Scope
# - Borough/District/County/Municipality/Administrative Area
# - Community Board/Neighborhood Council/Local Governance Area
# - Council District/City Council District/Legislative District
# - Department/Agency/Government Branch/Municipal Department
# - Location/Address/Site/Place/Site Description
# - GIS Property Number/Property ID/Parcel Number/Land Record Identifier
# - Precinct/Police Precinct/Service Area
# - OMP Property ID/Official Map Property ID
# - State Assembly District/Assemblyman's District/Legislative Assembly District
# - State Senate District/Senator's District/Legislative Senate District
# - Zip Code/Postal Code/ZIP+4
# - Spatial Role/Geospatial Function/Geographic Purpose
# - Boundary (Spatial Role)/Perimeter Line/Area Polygon
# - Multi-level Geometry/Hierarchical Geometry/Complex Spatial Data Type
# - Area-based Aggregation/Spatial Summarization/Zonal Statistics
# - Administrative-region Analysis/Jurisdictional Analysis/Political Boundary Analysis
# - Multipolygon/Multi-polygon Geometry/Complex Polygon Feature
# - Geographical Boundaries/Spatial Extent/Geographic Delineation
# - Parkland Distribution/Green Space Allocation/Open Space Coverage
# - Park Maintenance/Park Upkeep/Facility Management
# - Park Development/New Park Construction/Recreational Infrastructure
# - Recreational Zones/Activity Areas/Designated Use Zones
# - Urban Analysis/City Planning/Metropolitan Studies
# - Environmental Analysis/Ecological Studies/Conservation Science
#
# Keywords and Themes:
# - Parks
# - Park Zones
# - Green Spaces
# - Open Spaces
# - Recreational Areas
# - Parkland
# - Boundaries
# - GIS
# - Spatial Analysis
# - Urban Planning
# - Municipal Data
# - Land Use
# - Zoning
# - Acreage
# - Borough
# - Community Board
# - Council District
# - Department
# - Location
# - GIS Property Number
# - Precinct
# - OMP Property ID
# - State Assembly District
# - State Senate District
# - Zip Code
# - Multipolygon
# - Area Aggregation
# - Administrative Regions
# - Public Land
# - Conservation
# - Ecology
# - Infrastructure
#
# Additional Context:
# - This dataset is crucial for understanding the spatial distribution and administrative context of urban parkland. It supports interdisciplinary research combining urban planning, environmental science, and public policy by providing detailed geographic information linked to governmental administrative structures. Its granular data on park zones allows for precise analysis of green infrastructure, accessibility, and resource management within different municipal divisions. The dataset can be integrated with other urban datasets (e.g., population density, socio-economic indicators) to conduct comprehensive analyses of urban environments and community well-being.
# ==========================================================
# Generated descriptions stored for evaluation...

# %%
print(len(evaluation_records))
# Out:
# 5

# %% [markdown]
# ### 11. Evaluation

# %%
gold_data = {

    # D1 — Parking Meters Location and Status
    "NYC parking meters dataset": ["D1"],
    "parking availability street-level NYC": ["D1"],
    "NYC pay-by-cell parking infrastructure": ["D1"],
    "parking meter geolocation data": ["D1"],
    "NYC curbside parking enforcement planning data": ["D1"],

    # D2 — CPI Zones
    "community parks initiative boundaries NYC": ["D2"],
    "CPI zone polygons New York": ["D2"],
    "NYC park improvement program boundary files": ["D2"],
    "borough-level CPI analysis dataset": ["D2"],

    # D3 — Landmark Complaints
    "NYC landmark preservation complaints": ["D3"],
    "historic district violation reports NYC": ["D3"],
    "NYC construction and renovation complaint data": ["D3"],
    "spatio-temporal landmark complaint incidents": ["D3"],

    # D4 — Centerline
    "NYC street centerline dataset": ["D4"],
    "road geometry and street segment shapefile NYC": ["D4"],
    "transportation network polyline data NYC": ["D4"],
    "NYC street connectivity and width dataset": ["D4"],
    
    # D5 — Parks Zones
    "NYC park zones boundary polygons": ["D5"],
    "parkland administrative zones NYC": ["D5"],
    "parks acreage and boundary dataset NYC": ["D5"],
    "recreational area boundary shapefiles": ["D5"],

    # OVERLAP CASES
    # Purpose: evaluate retrieval ranking & discrimination ability
    
    # D1 + D3 (both point datasets, but different roles)
    "NYC point-based geospatial datasets for public services": ["D1", "D3"],
    "datasets with street-level point locations in NYC": ["D1", "D3"],

    # D2 + D5 (both boundary multipolygon but different themes)
    "NYC park-related boundary datasets": ["D2", "D5"],
    "datasets defining administrative park or community boundaries": ["D2", "D5"],

    # D1 + D4 (both infrastructure, point vs multi-line)
    "NYC street and parking infrastructure datasets": ["D1", "D4"],
    "NYC transportation and curbside infrastructure mapping": ["D1", "D4"],

    # D4 + D5 (street network + park zones)
    "NYC parks and surrounding street networks": ["D4", "D5"],

    # D2 + D4 (CPI zones + centerline)
    "NYC planning datasets with zones and street geometry": ["D2", "D4"],

    # FULL MULTI-DATASET (D1+D2+D3+D4+D5)
    "NYC geospatial datasets across multiple geometry types": ["D1", "D2", "D3", "D4", "D5"],
    "datasets supporting citywide spatial analysis NYC": ["D1", "D2", "D3", "D4", "D5"],

}

# %%
# Automatically extract descriptions from evaluation_record
baseline_descriptions = [rec["baseline_description"] for rec in evaluation_records]
geo_descriptions = [rec["geo_description"] for rec in evaluation_records]

# Generate dataset IDs: D1, D2, D3, ...
dataset_ids = [f"D{i+1}" for i in range(len(evaluation_records))]

# Build the corpora
corpus_baseline = {
    dataset_ids[i]: baseline_descriptions[i]
    for i in range(len(dataset_ids))
}

corpus_geo = {
    dataset_ids[i]: geo_descriptions[i]
    for i in range(len(dataset_ids))
}

print("Dataset IDs:", dataset_ids)
print("Baseline Corpus Keys:", corpus_baseline.keys())
print("Geo Corpus Keys:", corpus_geo.keys())
# Out:
# Dataset IDs: ['D1', 'D2', 'D3', 'D4', 'D5']
# Baseline Corpus Keys: dict_keys(['D1', 'D2', 'D3', 'D4', 'D5'])
# Geo Corpus Keys: dict_keys(['D1', 'D2', 'D3', 'D4', 'D5'])

# %% [markdown]
# ### 12. Retrieval Evaluation
# #### Retrieval Metric Definitions
#
# ###### | Metric      | Meaning (one line) |
# ###### | **Precision@K** | Fraction of retrieved items in the top-K that are relevant. |
# ###### | **Recall@K** | Fraction of all relevant items that appear in the top-K. |
# ###### | **Hit@K** | Indicates whether at least one relevant item appears in the top-K (averaged across queries). |
# ###### | **MRR (Mean Reciprocal Rank)** | Measures how early the first relevant item appears in the ranking. |
# ###### | **nDCG@K** | Evaluates ranking quality by rewarding relevant items placed higher in the top-K. |
# ###### | **MAP (Mean Average Precision)** | Measures overall ranking quality across all relevant items for each query. |

# %%
import numpy as np
import pandas as pd
from rank_bm25 import BM25Okapi
import math

def dcg_at_k(r, k):
    """Discounted Cumulative Gain"""
    r = np.asarray(r, dtype=float)[:k]
    if r.size:
        return np.sum(r / np.log2(np.arange(2, r.size + 2)))
    return 0.0

def ndcg_at_k(r, k):
    """Normalized DCG"""
    best_r = sorted(r, reverse=True)
    return dcg_at_k(r, k) / (dcg_at_k(best_r, k) or 1.0)

def average_precision(ranked_list, relevant_set):
    """AP for multi-label relevance"""
    hits = 0
    sum_precisions = 0
    for i, d in enumerate(ranked_list):
        if d in relevant_set:
            hits += 1
            sum_precisions += hits / (i + 1)
    if len(relevant_set) == 0:
        return 0
    return sum_precisions / len(relevant_set)

def eval_corpus(corpus, gold, k=2):
    dataset_ids = list(corpus.keys())
    tokenized = [corpus[d].lower().split() for d in dataset_ids]
    bm25 = BM25Okapi(tokenized)

    metrics = {
        "Precision@K": [],
        "Recall@K": [],
        "Hit@K": [],
        "MRR": [],
        "nDCG@K": [],
        "MAP": []
    }

    for query, relevant in gold.items():
        relevant = set(relevant)

        # Retrieve ranked list
        scores = bm25.get_scores(query.lower().split())
        ranked = [dataset_ids[i] for i in np.argsort(scores)[::-1]]
        top_k = ranked[:k]

        # Relevance mask for ranking
        relevance_mask = [1 if d in relevant else 0 for d in ranked]

        # Precision and recall
        hits = sum([1 for d in top_k if d in relevant])
        precision = hits / k
        recall = hits / (len(relevant) or 1)

        # Hit@K (boolean)
        hitk = 1 if hits > 0 else 0

        # MRR (first relevant rank)
        rr = 0
        for i, d in enumerate(ranked):
            if d in relevant:
                rr = 1 / (i + 1)
                break

        # nDCG@K
        ndcg = ndcg_at_k(relevance_mask, k)

        # MAP
        ap = average_precision(ranked, relevant)

        # Store
        metrics["Precision@K"].append(precision)
        metrics["Recall@K"].append(recall)
        metrics["Hit@K"].append(hitk)
        metrics["MRR"].append(rr)
        metrics["nDCG@K"].append(ndcg)
        metrics["MAP"].append(ap)

    # Return macro averages as a table
    results_df = pd.DataFrame({
        metric: [np.mean(values)]
        for metric, values in metrics.items()
    })

    return results_df

# %%
baseline_scores = eval_corpus(corpus_baseline, gold_data)
geo_scores = eval_corpus(corpus_geo, gold_data)

comparison_df = pd.DataFrame({
    "Model": ["Baseline", "AutoDDG-Geo"]
})

for col in baseline_scores.columns:
    comparison_df[col] = [baseline_scores[col].iloc[0], geo_scores[col].iloc[0]]

comparison_df
# Out:
#          Model  Precision@K  Recall@K     Hit@K       MRR    nDCG@K       MAP
# 0     Baseline     0.564516  0.848387  0.935484  0.889785  0.855030  0.877419
# 1  AutoDDG-Geo     0.580645  0.880645  0.967742  0.911290  0.882683  0.893280

# %% [markdown]
# ### 13. Geospatial Faithfulness Score

# %%
POINT_TERMS = ["point", "point-based", "latitude", "longitude"]
POLYGON_TERMS = ["polygon", "polygon-based", "boundary"]
POLYLINE_TERMS = ["polyline", "line", "centerline"]
MULTI_TERMS = ["multi", "multi polygon", "multipolygon"]

EVENT_TERMS = ["event", "event", "event", "incident"]
INFRA_TERMS = ["infrastructure", "fixed infrastructure"]
BOUNDARY_TERMS = ["boundary", "boundary", "administrative boundary"]
OBSERVATION_TERMS = ["observation", "observational data", "sensor-based observation"]

# %%
def extract_geo_features(text):
    text = text.lower()
    feats = set()

    if any(w in text for w in POINT_TERMS): feats.add("point")
    if any(w in text for w in POLYGON_TERMS): feats.add("polygon")
    if any(w in text for w in POLYLINE_TERMS): feats.add("polyline")
    if any(w in text for w in MULTI_TERMS): feats.add("multi")
    if "multi" in feats:
        feats.add("polygon")

    if any(w in text for w in EVENT_TERMS): feats.add("event")
    if any(w in text for w in INFRA_TERMS): feats.add("infrastructure")
    if any(w in text for w in BOUNDARY_TERMS): feats.add("boundary")
    if any(w in text for w in OBSERVATION_TERMS): feats.add("observation")

    return feats
    
def geospatial_faithfulness(geo_profile, description_features):
    score = 0
    total = 2  # geometry + role

    # geometry match
    if geo_profile.geometry_type in description_features:
        score += 1

    # spatial role match
    if geo_profile.spatial_role in description_features:
        score += 1

    return score / total

def compute_faithfulness_scores(evaluation_record):
    rows = []

    for i, rec in enumerate(evaluation_record):
        dataset_id = f"D{i+1}"

        gp = rec["geo_profile"]

        # extract features
        baseline_feats = extract_geo_features(rec["baseline_description"])
        geo_desc_feats = extract_geo_features(rec["geo_description"])

        # compute scores
        baseline_gfs = geospatial_faithfulness(gp, baseline_feats)
        geo_gfs = geospatial_faithfulness(gp, geo_desc_feats)

        rows.append({
            "Dataset": dataset_id,
            "Spatial Role": gp.spatial_role,
            "Geometry Type": gp.geometry_type,
            "Baseline GFS": baseline_gfs,
            "Geo GFS": geo_gfs
        })

    return pd.DataFrame(rows)

# %%
faithfulness_table = compute_faithfulness_scores(evaluation_records)
faithfulness_table
# Out:
#   Dataset    Spatial Role Geometry Type  Baseline GFS  Geo GFS
# 0      D1  infrastructure         point           0.5      1.0
# 1      D2        boundary         multi           0.5      1.0
# 2      D3           event         point           0.5      1.0
# 3      D4  infrastructure         multi           0.5      1.0
# 4      D5        boundary         multi           0.5      1.0
