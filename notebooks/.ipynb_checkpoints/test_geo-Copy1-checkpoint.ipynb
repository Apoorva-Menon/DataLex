# %% [markdown]
# ### 1. Imports

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from google import genai
from autoddg import AutoDDG
import pandas as pd
from pathlib import Path
from geo_profiler.geo_profiler import GeoProfiler
from geo_profiler.models import GeoProfile
from autoddg_geo import AutoDDGGeo
from openai import OpenAI
import time
from rank_bm25 import BM25Okapi
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2. Setting up Open AI Client, AutoDDG and AutoDDG-Geo

# %%
PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

# Setup OpenAI client
client = OpenAI(
    api_key="AIzaSyBaUUM696KvYfr0P-vN0qR64v3v6_zrfNU",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# Initialize AutoDDG and AutoDDG Geo
autoddg = AutoDDG(client=client, model_name="gemini-2.5-flash-lite")
autoddg_geo = AutoDDGGeo(client=client, model_name="gemini-2.5-flash-lite")

# %% [markdown]
# ### 3. Reading dataset

# %%
def read_dataset(path: str):
    sample_csv = pd.read_csv(path)
    print(sample_csv.shape)
    return sample_csv

# %% [markdown]
# ### 4. Retrieving data profile

# %%
def infer_data_profile(dataframe: pd.DataFrame) -> str:
    dataprofile = autoddg.profile_dataframe(dataframe=dataframe)
    return dataprofile

# %% [markdown]
# ### 5. Deriving Semantic Profile

# %%
def infer_semantic_profile(dataframe: pd.DataFrame) -> str:
    semantic_profile = autoddg.analyze_semantics(dataframe=dataframe)
    return semantic_profile

# %% [markdown]
# ### 6. Deriving Geo Spatial Profile

# %%
def infer_geo_profile(semantic_profile: str, df: pd.DataFrame) -> GeoProfile: 
    geo_profile = autoddg_geo.analyze_geo(semantic_profile, df)
    return geo_profile

# %% [markdown]
# ### 7. Deriving AutoDDG Description

# %%
def generate_dataset_description(sample_csv, dataprofile, use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic):
    prompt, desc = autoddg.describe_dataset(sample_csv, dataprofile[0], use_data_profile, semantic_profile, use_semantic_profile)
    return desc

# %% [markdown]
# ### 8. Deriving Geo Aware Description

# %%
def generate_geoaware_description(sample_csv, dataprofile, use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic, geo_profile, use_geo_profile):
    geo_desc = autoddg_geo.generate_geoaware_description(sample_csv, dataprofile[0], use_data_profile, semantic_profile, use_semantic_profile, topic, use_topic, geo_profile, use_geo_profile)
    return geo_desc[0]

# %% [markdown]
# ### 9. Expanding Geo Aware Description for Search

# %%
def generate_description_for_search(desc, topic):
    search_desc = autoddg.expand_description_for_search(desc, topic)
    return search_desc[1]

# %% [markdown]
# ### 10. Generating Descriptions for Various Datasets:

# %%
evaluation_records = []

# %%
def generating_descriptions(topic, dataset_path):

    print(f"Read Dataset {topic}:")
    df = read_dataset(dataset_path)
    df_sample = df.head(5)
    sample_csv = df_sample.to_csv(index=False)
    print("==========================================================")
    print("Infer data profile:")
    dataprofile = infer_data_profile(df)
    print(dataprofile[0])
    print("==========================================================")
    print("Infer semantic profile:")
    semantic_profile = infer_semantic_profile(df)
    print(semantic_profile)
    time.sleep(60)
    print("==========================================================")
    print("Infer geo profile:")
    geo_profile = infer_geo_profile(semantic_profile, df_sample)
    print(geo_profile)
    print("==========================================================")
    print("Generated user focused AutoDDG description:")
    autoddg_desc = generate_dataset_description(sample_csv, dataprofile[0], True, semantic_profile, True, topic, True)
    print(autoddg_desc)
    time.sleep(60)
    print("==========================================================")
    print("Generated user focused description with Geo profile:")
    autoddg_geo_desc = generate_geoaware_description(sample_csv, dataprofile[0], True, semantic_profile, True, topic, True, geo_profile, True)
    print(autoddg_geo_desc)
    time.sleep(60)
    print("==========================================================")
    print("Generated search focused description with Geo description:")
    search_desc = generate_description_for_search(autoddg_geo_desc, topic)
    print(search_desc)
    print("==========================================================")
    evaluation_records.append({
        "topic": topic,
        "dataset_name": df,
        "data_profile": dataprofile[0],
        "semantic_profile": semantic_profile,
        "geo_profile": geo_profile,
        "baseline_description": autoddg_desc,
        "geo_description": autoddg_geo_desc,
        "search_description": search_desc
    })

# %% [markdown]
# ### 10. 1 - Dataset 1: Parking Meters Locations and Status
# ##### https://data.cityofnewyork.us/Transportation/Parking-Meters-Locations-and-Status/693u-uax6/about_data

# %%
topic = "Parking Meters Locations and Status"
csv_path = "../examples/Parking_Meters_Locations_and_Status.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Parking Meters Locations and Status:
# (15582, 17)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **ObjectID**: Data is of type integer. There are 15582 unique values. Coverage spans from 0 to 15326.0.
# **Meter Number**: Data is of type integer. There are 15576 unique values. Coverage spans from 0 to 5043005.0.
# **Status**: Data is of type text. There are 3 unique values.
# **Pay By Cell Number**: Data is of type integer. There are 12092 unique values. Coverage spans from 0 to 509514.0.
# **Meter_Hours**: Data is of type text.
# **Parking_Facility_Name**: Data is of type text. There are 35 unique values.
# **Facility**: Data is of type text. There are 3 unique values.
# **Borough**: Data is of type text. There are 5 unique values.
# **On_Street**: Data is of type text. There are 1446 unique values.
# **Side_of_Street**: Data is of type text. There are 13 unique values.
# **From_Street**: Data is of type text. There are 2341 unique values.
# **To_Street**: Data is of type text. There are 2334 unique values.
# **Latitude**: Data is of type float. Coverage spans from 0 to 40.88751899863.
# **Longitude**: Data is of type float. Coverage spans from -74.02828691761 to 0.
# **X**: Data is of type text. There are 15566 unique values.
# **Y**: Data is of type text. There are 15568 unique values.
# **Location**: Data is of type geocoordinates.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **ObjectID**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **Meter Number**: Represents identifier. Domain-specific type: utilities. Function/Usage context: measurement.
# **Status**: Represents status indicator. Domain-specific type: general. Function/Usage context: categorical filter.
# **Pay By Cell Number**: Represents identifier. Domain-specific type: payment. Function/Usage context: identifier.
# **Meter_Hours**: Represents time information. Contains temporal data (resolution: Hour). Domain-specific type: general. Function/Usage context: measurement.
# **Parking_Facility_Name**: Represents location/facility. Domain-specific type: transportation/urban planning. Function/Usage context: identifier.
# **Facility**: Represents location type. Domain-specific type: general.
# **Borough**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: demographic. Function/Usage context: aggregation key.
# **On_Street**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: general. Function/Usage context: identifier.
# **Side_of_Street**: Represents directional identifier. Contains spatial data (resolution: Direction). Domain-specific type: general. Function/Usage context: descriptive attribute.
# **From_Street**: Represents location. Contains spatial data (resolution: Street Name). Domain-specific type: geographic. Function/Usage context: location identifier.
# **To_Street**: Represents location. Contains spatial data (resolution: Street). Domain-specific type: geographic. Function/Usage context: address component.
# **Latitude**: Represents location data. Contains spatial data (resolution: Coordinates). Domain-specific type: geographic. Function/Usage context: measurement.
# **Longitude**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: geographic. Function/Usage context: measurement.
# **X**: Represents numerical value. Domain-specific type: general. Function/Usage context: measurement.
# **Y**: Represents numeric value. Contains temporal data (resolution: ). Contains spatial data (resolution: ). Domain-specific type: general. Function/Usage context: measurement.
# **Location**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: general. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='infrastructure', geometry_type='point', spatial_resolution='multi-level', spatial_use_cases=['accessibility mapping', 'navigation support', 'facility density analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains information about parking meters, including their unique object and meter numbers, status, and payment by cell number. It details the operational hours for metered parking, specifying restrictions like "2HR Pas Mon-Sat 0830-1800". The data also provides precise location information for each meter, including the street name, side of the street, intersecting streets, and geographical coordinates (latitude and longitude). Parking facility names and types are also included, along with the borough in which the meter is located. The dataset is useful for understanding parking regulations and spatial distribution within the city.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset represents parking meter locations and status, containing information about individual parking meters including their unique ObjectID and Meter Number, operational Status, and a Pay By Cell Number for payment. Meter_Hours indicates the operational hours for parking. The dataset details the spatial attributes of each meter, such as the Parking_Facility_Name, Facility type, Borough, On_Street, Side_of_Street, From_Street, and To_Street, along with precise Latitude and Longitude coordinates. The data is structured with a point geometry type and a multi-level spatial resolution, making it suitable for accessibility mapping, navigation support, and facility density analysis. The dataset's topic, Parking Meters Locations and Status, supports analytical applications such as optimizing parking enforcement routes, planning for new parking infrastructure, and understanding parking availability across different boroughs.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset represents parking meter locations and status, containing information about individual parking meters including their unique ObjectID and Meter Number, operational Status, and a Pay By Cell Number for payment. Meter_Hours indicates the operational hours for parking. The dataset details the spatial attributes of each meter, such as the Parking_Facility_Name, Facility type, Borough, On_Street, Side_of_Street, From_Street, and To_Street, along with precise Latitude and Longitude coordinates. The data is structured with a point geometry type and a multi-level spatial resolution, making it suitable for accessibility mapping, navigation support, and facility density analysis. The dataset's topic, Parking Meters Locations and Status, supports analytical applications such as optimizing parking enforcement routes, planning for new parking infrastructure, and understanding parking availability across different boroughs.
#
# Key Themes or Topics:
# - Transportation infrastructure/Urban mobility
# - Public space management/City services
# - Real estate and property management/Land use
# - Civic technology/Smart city initiatives
# - Geospatial data/Spatial analysis
#
# Applications and Use Cases:
# - Parking meter management/Enforcement optimization
# - Urban planning/Infrastructure development
# - Navigation and wayfinding/Accessibility mapping
# - Facility location analysis/Density assessment
# - Transportation demand management/Parking policy analysis
# - Smart city implementation/IoT deployment
#
# Concepts and Synonyms:
# - Parking meters/Parking meters locations/Parking meter status/Parking meter data
# - Metered parking/Pay and display machines/Parking payment systems
# - On-street parking/Curb parking
# - Off-street parking/Parking facilities/Parking garages/Parking lots
# - Pay by phone parking/Mobile payment parking/App-based parking
# - Parking hours/Operational hours/Service hours
# - Meter number/Asset ID/Meter identifier
# - ObjectID/Object identifier/Record ID
# - Status/Operational status/Meter condition/Availability
# - Location/Coordinates/Geographic coordinates/Latitude/Longitude/Spatial data/Point data
# - Street segment/Road segment/From street/To street
# - Side of street/Street direction
# - Borough/Administrative division/Neighborhood
# - Parking facility name/Facility name
# - Facility type/Type of parking facility
# - Accessibility/Spatial accessibility
# - Navigation/Wayfinding
# - Density analysis/Facility density
# - Parking enforcement/Parking control
# - Urban planning/City planning/Municipal planning
# - Infrastructure planning/New parking infrastructure
# - Parking availability/Parking supply
# - Civic engagement/Public services
# - Geospatial analysis/Spatial analysis/GIS (Geographic Information Systems)
#
# Keywords and Themes:
# - Parking Meters
# - Metered Parking
# - Parking Locations
# - Parking Status
# - Pay by Cell
# - Meter Hours
# - Parking Facility
# - Street Parking
# - On-Street Parking
# - Off-Street Parking
# - Borough
# - Latitude
# - Longitude
# - Spatial Data
# - Urban Planning
# - Transportation
# - Mobility
# - City Services
# - Smart City
# - GIS
# - Navigation
# - Accessibility
# - Enforcement
# - Infrastructure
#
# Additional Context:
# - This dataset is crucial for understanding the distribution and operational status of parking meters within a city, directly impacting urban mobility and the efficiency of parking management.
# - It can be integrated with datasets on traffic flow, public transit, or pedestrian activity to provide a more comprehensive view of urban transportation dynamics.
# - The spatial information allows for detailed analysis of parking access in relation to amenities, businesses, and residential areas, supporting equitable service distribution and urban development strategies.
# - Understanding parking meter status can inform dynamic pricing strategies and real-time availability information for drivers.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### 10.2 - Dataset 2: Community Parks Initiative Zone Boundaries
# ##### https://data.cityofnewyork.us/City-Government/Community-Parks-Initiative-Zone-Boundaries/vvdx-b56i

# %%
topic = "Community Parks Initiative Zone Boundaries"
csv_path = "../examples/CPI_Zones.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Community Parks Initiative Zone Boundaries:
# (55, 8)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **the_geom**: Data is of type text.
# **BoroCode**: Data is of type integer. There are 5 unique values. Coverage spans from 0 to 5.0.
# **BoroName**: Data is of type text. There are 5 unique values.
# **CountyFIPS**: Data is of type integer. There are 5 unique values. Coverage spans from 0 to 85.0.
# **NTACode**: Data is of type text. There are 55 unique values.
# **NTAName**: Data is of type text. There are 55 unique values.
# **Shape_Leng**: Data is of type text. There are 55 unique values.
# **Shape_Area**: Data is of type text. There are 55 unique values.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **the_geom**: Represents geographic entity. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: spatial representation.
# **BoroCode**: Represents geographic entity. Domain-specific type: urban planning/administration. Function/Usage context: identifier/code.
# **BoroName**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: urban geography. Function/Usage context: geographic identifier.
# **CountyFIPS**: Represents location. Contains spatial data (resolution: County). Domain-specific type: demographic. Function/Usage context: identifier.
# **NTACode**: Represents location identifier. Contains spatial data (resolution: Neighborhood/District). Domain-specific type: demographic/urban planning. Function/Usage context: geographic identifier/categorization.
# **NTAName**: Represents location. Contains spatial data (resolution: Neighborhood/Area). Domain-specific type: geographic. Function/Usage context: geographic identifier.
# **Shape_Leng**: Represents measurement. Domain-specific type: geospatial. Function/Usage context: measurement.
# **Shape_Area**: Represents measurement. Domain-specific type: geospatial. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='observation', geometry_type='multi', spatial_resolution='multi-level', spatial_use_cases=['location inventory', 'sensor mapping', 'proximity analysis'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains geospatial information for various neighborhoods within New York City. It includes the geometric shape of each area, identified by borough code and name, as well as county FIPS code, NTA code, and NTA name. The dataset also provides measurements for the length and area of each shape. This data is useful for urban planning, demographic analysis, and geographic research within New York City.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset represents Community Parks Initiative Zone Boundaries and contains geospatial information about various administrative and geographic areas. The dataset's spatial role is an observation, with a multi-level spatial resolution and a multi-polygon geometry type, enabling location inventory, sensor mapping, and proximity analysis. Each record includes a `the_geom` column detailing the geographic entity's spatial representation through coordinates. Administrative identifiers are provided through `BoroCode`, `BoroName`, `CountyFIPS`, `NTACode`, and `NTAName`, which specify borough, county, and neighborhood or district information. Measurements of the geographic entities are captured in `Shape_Leng` and `Shape_Area`. This data is suitable for analytical applications such as planning new park initiatives within specific zones, operational tasks like managing park resources based on their boundaries, and for conducting proximity analyses to understand the spatial relationships between park zones and other geographic features.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset represents Community Parks Initiative Zone Boundaries and contains geospatial information about various administrative and geographic areas. The dataset's spatial role is an observation, with a multi-level spatial resolution and a multi-polygon geometry type, enabling location inventory, sensor mapping, and proximity analysis. Each record includes a `the_geom` column detailing the geographic entity's spatial representation through coordinates. Administrative identifiers are provided through `BoroCode`, `BoroName`, `CountyFIPS`, `NTACode`, and `NTAName`, which specify borough, county, and neighborhood or district information. Measurements of the geographic entities are captured in `Shape_Leng` and `Shape_Area`. This data is suitable for analytical applications such as planning new park initiatives within specific zones, operational tasks like managing park resources based on their boundaries, and for conducting proximity analyses to understand the spatial relationships between park zones and other geographic features.
#
# Key Themes or Topics:
# - Community Parks Initiative/Parks Planning and Development
# - Urban Planning and Design
# - Geospatial Analysis and Mapping
# - Administrative and Geographic Zoning
# - Public Space Management
# - Environmental Planning and Conservation
#
# Applications and Use Cases:
# - Community park planning and development
# - Urban infrastructure planning
# - Geospatial data analysis
# - Location-based services
# - Environmental impact assessment
# - Public health initiatives planning
# - Neighborhood revitalization strategies
# - Resource allocation for parks and recreation
# - Spatial modeling for urban development
# - Property analysis and land use planning
# - Public access and equitable distribution analysis
# - Census tract and administrative boundary analysis
#
# Concepts and Synonyms:
# - Community Parks Initiative/CPI Zone/CPI Boundary
# - Park Zones/Park Districts/Park Areas
# - Initiative Zones/Program Zones/Project Zones
# - Geospatial Data/Spatial Data/Geographic Information
# - Boundaries/Limits/Perimeters/Extents
# - Administrative Areas/Boroughs/Counties/Neighborhoods/Districts/NTAs
# - BoroCode/Borough Code/Borough Identifier
# - BoroName/Borough Name
# - CountyFIPS/County Federal Information Processing Standards
# - NTACode/Neighborhood Tabulation Area Code
# - NTAName/Neighborhood Tabulation Area Name
# - Multi-polygon Geometry/Polygon Data/Shape Data
# - Spatial Resolution/Geographic Resolution
# - Location Inventory/Asset Mapping
# - Sensor Mapping/Geographic Tagging
# - Proximity Analysis/Spatial Relationships/Distance Analysis
# - Planning/Strategic Planning/Development Planning
# - Operational Tasks/Management/Resource Management
# - Shape_Leng/Shape Length/Perimeter Measurement
# - Shape_Area/Shape Area/Surface Area Measurement
# - Analytical Applications/Data Analysis/Statistical Analysis
# - Public Space/Green Space/Open Space
# - Urban Development/City Planning
# - Land Use/Zoning Regulations
#
# Keywords and Themes:
# - Community Parks Initiative
# - Zone Boundaries
# - Geospatial
# - Spatial
# - Multi-polygon
# - Observation
# - Administrative Boundaries
# - Geographic Areas
# - BoroCode
# - BoroName
# - CountyFIPS
# - NTACode
# - NTAName
# - Shape_Leng
# - Shape_Area
# - Location Inventory
# - Sensor Mapping
# - Proximity Analysis
# - Park Planning
# - Urban Planning
# - Public Space
# - Green Space
# - Initiative
# - Development
# - Management
# - Analysis
# - Mapping
# - Zoning
# - Neighborhoods
# - Districts
# - Boroughs
# - Counties
# - NYC Parks
#
# Additional Context:
# - This dataset is crucial for understanding the spatial distribution and administrative context of areas designated for the Community Parks Initiative.
# - It supports data-driven decision-making in urban planning, park development, and resource allocation.
# - Enables analysis of equitable access to park resources across different boroughs and neighborhoods.
# - Can be integrated with demographic, socio-economic, or environmental datasets for more comprehensive studies on urban development and community well-being.
# - Useful for identifying underserved areas or opportunities for new park development based on existing initiative zones.
# ==========================================================
# Generated descriptions stored for evaluation...

# %% [markdown]
# ### 10.3 - Dataset 3: Landmarks Complaints
# ##### https://data.cityofnewyork.us/Housing-Development/Landmarks-Complaints/ck4n-5h6x/about_data

# %%
topic = "Landmark Complaints"
csv_path = "../examples/Landmarks_Complaints.csv"
print("Generating descriptions...")
generating_descriptions(topic, csv_path)
print("Generated descriptions stored for evaluation...")
# Out:
# Generating descriptions...
# Read Dataset Landmark Complaints:
# (6689, 18)
# ==========================================================
# Infer data profile:
# The key data profile information for this dataset includes:
# **Complaint #**: Data is of type text. There are 6686 unique values.
# **Date**: Data is of type text. There are 2727 unique values.
# **Address #**: Data is of type text. There are 1646 unique values.
# **Street Name**: Data is of type text. There are 1382 unique values.
# **Borough**: Data is of type text. There are 11 unique values.
# **Block**: Data is of type integer. There are 1338 unique values. Coverage spans from 0 to 2476.0.
# **Lot**: Data is of type integer. There are 243 unique values. Coverage spans from 0 to 93.0.
# **BIN**: Data is of type integer. There are 4790 unique values. Coverage spans from 0 to 5015074.0.
# **Postcode**: Data is of type integer. There are 149 unique values. Coverage spans from 0 to 11377.0.
# **Landmark Name**: Data is of type text.
# **Work Reported**: Data is of type text.
# **Action Taken**: Data is of type text. There are 3 unique values.
# **Status**: Data is of type text. There are 2 unique values.
# **Council District**: Data is of type integer. There are 50 unique values. Coverage spans from 0 to 47.0.
# **Community Board**: Data is of type text. There are 79 unique values.
# **NTA**: Data is of type text. There are 120 unique values.
# **Latitude**: Data is of type float. Coverage spans from 0 to 40.85158633446.
# **Longitude**: Data is of type float. Coverage spans from -74.00983034663 to 0.
# ==========================================================
# Infer semantic profile:
# The key semantic information for this dataset includes:
# **Complaint #**: Represents identifier. Domain-specific type: customer service. Function/Usage context: identifier.
# **Date**: Represents temporal entity. Contains temporal data (resolution: Day). Domain-specific type: general. Function/Usage context: aggregation key.
# **Address #**: Represents address. Domain-specific type: general. Function/Usage context: identifier.
# **Street Name**: Represents location. Contains spatial data (resolution: Street). Domain-specific type: general. Function/Usage context: descriptive.
# **Borough**: Represents location. Contains spatial data (resolution: Borough). Domain-specific type: urban planning. Function/Usage context: geographic identifier.
# **Block**: Represents numeric entity. Domain-specific type: general. Function/Usage context: measurement.
# **Lot**: Represents identifier. Domain-specific type: inventory/manufacturing. Function/Usage context: identification/tracking.
# **BIN**: Represents identifier. Domain-specific type: general. Function/Usage context: identifier.
# **Postcode**: Represents location. Contains spatial data (resolution: Postal Code). Domain-specific type: geographic. Function/Usage context: identifier.
# **Landmark Name**: Represents location. Contains spatial data (resolution: District). Domain-specific type: cultural heritage. Function/Usage context: identifier.
# **Work Reported**: Represents work description. Domain-specific type: construction/permitting. Function/Usage context: description.
# **Action Taken**: Represents action/status. Domain-specific type: regulatory/compliance. Function/Usage context: categorical data.
# **Status**: Represents status. Domain-specific type: general. Function/Usage context: categorical feature.
# **Council District**: Represents geographic area. Contains spatial data (resolution: District). Domain-specific type: governmental/civic. Function/Usage context: geographic identifier.
# **Community Board**: Represents geographic region. Domain-specific type: demographic. Function/Usage context: categorization/grouping.
# **NTA**: Represents location. Contains spatial data (resolution: Neighborhood). Domain-specific type: demographic. Function/Usage context: geographic identifier.
# **Latitude**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: geographic. Function/Usage context: measurement.
# **Longitude**: Represents location. Contains spatial data (resolution: Coordinates). Domain-specific type: geospatial. Function/Usage context: measurement.
# ==========================================================
# Infer geo profile:
# GeoProfile(spatial_role='event', geometry_type='point', spatial_resolution='multi-level', spatial_use_cases=['spatio-temporal incident analysis', 'hotspot mapping', 'event clustering', 'trend analysis over time'])
# ==========================================================
# Generated user focused AutoDDG description:
# This dataset contains records of construction-related complaints, including the complaint number, date, and address. It details the street name, borough, block, lot, building identification number (BIN), and postcode for each complaint. The dataset also includes information on landmark names, the type of work reported, and the action taken and status of the complaint. Geographic identifiers such as council district, community board, and NTA (Neighborhood Tabulation Area) are provided, along with latitude and longitude coordinates for precise location. This data is valuable for understanding construction activities and regulatory responses within specific urban areas.
# ==========================================================
# Generated user focused description with Geo profile:
# This dataset contains records of landmark complaints, with each entry identified by a unique Complaint #. The data includes the Date of the complaint, along with detailed location information such as Address #, Street Name, Borough, Postcode, and specific geographic identifiers like Council District, Community Board, and NTA (Neighborhood). For each complaint, the dataset records the Block and Lot numbers, and a Building Identification Number (BIN). It also captures the Landmark Name associated with the complaint, a description of the Work Reported, and the Action Taken and Status of the complaint. Geographically, the dataset is structured as point data with a multi-level spatial resolution, enabling spatio-temporal incident analysis, hotspot mapping, event clustering, and trend analysis over time. This information is valuable for analyzing patterns in landmark complaints, understanding the types of work being reported without permits, and assessing the effectiveness of regulatory actions taken.
# ==========================================================
# Generated search focused description with Geo description:
# Dataset Overview:
# - This dataset contains records of landmark complaints, with each entry identified by a unique Complaint #. The data includes the Date of the complaint, along with detailed location information such as Address #, Street Name, Borough, Postcode, and specific geographic identifiers like Council District, Community Board, and NTA (Neighborhood). For each complaint, the dataset records the Block and Lot numbers, and a Building Identification Number (BIN). It also captures the Landmark Name associated with the complaint, a description of the Work Reported, and the Action Taken and Status of the complaint. Geographically, the dataset is structured as point data with a multi-level spatial resolution, enabling spatio-temporal incident analysis, hotspot mapping, event clustering, and trend analysis over time. This information is valuable for analyzing patterns in landmark complaints, understanding the types of work being reported without permits, and assessing the effectiveness of regulatory actions taken.
#
# Key Themes or Topics:
# - Historic Preservation/Landmark Protection
# - Urban Development/Building Regulations
# - Municipal Enforcement/Code Violations
# - Architectural Heritage/Cultural Resources Management
# - Property Management/Real Estate
# - Geographic Information Systems (GIS)/Spatial Analysis
#
# Applications and Use Cases:
# - Historic Site Management/Preservation Planning
# - Urban Planning/Zoning Enforcement
# - Policy Development/Regulatory Review
# - Permit Violation Detection/Illegal Construction Monitoring
# - Building Safety Inspections/Compliance Audits
# - Statistical Analysis/Trend Forecasting
# - Hotspot Identification/Geospatial Crime Mapping (analogous to complaint mapping)
# - Event Clustering/Spatial Pattern Recognition
# - Public Engagement/Citizen Reporting Analysis
#
# Concepts and Synonyms:
# - Landmark Complaints/Historic Building Complaints/Heritage Site Complaints
# - Complaint #/Case Number/Incident ID
# - Date/Timestamp/Complaint Date
# - Address/Street/Location/Site
# - Borough/County/District
# - Postcode/Zip Code
# - Council District/Supervisory District/Ward
# - Community Board/Local Advisory Board
# - NTA (Neighborhood)/Neighborhood Tabulation Area/Census Tract
# - Block/Tax Block/Parcel Block
# - Lot/Tax Lot/Parcel Lot
# - BIN (Building Identification Number)/Building ID
# - Landmark Name/Historic Designation/Protected Site
# - Work Reported/Activity Description/Violation Description/Construction Details
# - Action Taken/Enforcement Action/Resolution
# - Status/Case Status/Complaint Resolution
# - Spatio-temporal Analysis/Geospatial Temporal Analysis
# - Hotspot Mapping/Density Mapping/Clustering Analysis
# - Event Clustering/Incident Grouping
# - Trend Analysis/Time Series Analysis
# - Permit Violations/Unpermitted Work/Illegal Construction/Unauthorized Alterations
# - Regulatory Compliance/Code Enforcement/Building Code Violations
# - Public Safety/Building Integrity
# - Cultural Heritage/Architectural Significance
# - Property Records/Real Estate Data
# - Geographic Data/Spatial Data/Point Data
#
# Keywords and Themes:
# - Landmarks
# - Historic Buildings
# - Preservation
# - Complaints
# - Violations
# - Enforcement
# - Regulations
# - Building Permits
# - Construction
# - Urban Planning
# - GIS
# - Spatial Analysis
# - Hotspots
# - Trends
# - Municipal Services
# - Code Enforcement
# - Architectural Heritage
# - Cultural Resources
# - Property
# - Address
# - Location
# - Date
# - Status
# - Action
# - BIN
# - NTA
# - Borough
# - Council District
# - Community Board
# - Block and Lot
#
# Additional Context:
# - This dataset is crucial for understanding the dynamics of protecting designated landmarks and historic structures within an urban environment. It provides granular data for identifying areas or types of landmarks that are frequently subject to complaints, potentially indicating areas with high risk of unpermitted work or neglect. The spatial and temporal resolution allows for the mapping of complaint patterns and the evaluation of the effectiveness of enforcement strategies over time. This data can be integrated with other datasets related to building permits, historical surveys, and demographic information to conduct more comprehensive analyses of urban heritage management and development pressures.
# ==========================================================
# Generated descriptions stored for evaluation...

# %%
print(len(evaluation_records))
# Out:
# 3

# %% [markdown]
# ### 10. Evaluation

# %%
gold_data = {

  # EVENT-SPECIFIC (only D3)
  "NYC landmark complaints": ["D3"],
  "historic district violations NYC": ["D3"],
  "NYC construction complaint hotspots": ["D3"],
  "spatio-temporal incident clustering NYC": ["D3"],

  # INFRASTRUCTURE-SPECIFIC (only D1)
  "parking meters locations NYC": ["D1"],
  "street parking availability map": ["D1"],
  "NYC parking infrastructure dataset": ["D1"],

  # BOUNDARY-SPECIFIC (only D2)
  "NYC administrative district polygons": ["D2"],
  "community parks initiative zones": ["D2"],
  "borough-level park boundary maps": ["D2"],

  # MULTI-DATASET QUERIES (D1 + D3)
  "NYC street-level geospatial datasets": ["D1", "D3"],
  "NYC datasets with latitude and longitude for mapping": ["D1", "D3"],

  # MULTI-DATASET QUERIES (D2 + D3)
  "NYC neighborhood-level spatial analysis": ["D2", "D3"],
  "datasets with NTA-level spatial attributes NYC": ["D2", "D3"],

  # MULTI-DATASET QUERIES (D1 + D2)
  "NYC urban planning datasets": ["D1", "D2"],
  "NYC street + zone geospatial datasets": ["D1", "D2"],

  # MULTI-DATASET GENERAL QUERY (D1 + D2 + D3)
  "NYC geospatial datasets for multi-scale analysis": ["D1", "D2", "D3"],
  "datasets supporting citywide spatial analysis": ["D1", "D2", "D3"],
}

# %%
corpus_baseline = {
  "D1": baseline_desc_1,
  "D2": baseline_desc_2
}

corpus_geo = {
  "D1": geo_desc_1,
  "D2": geo_desc_2
}

# %%
import numpy as np
import pandas as pd
from rank_bm25 import BM25Okapi
import math

def dcg_at_k(r, k):
    """Discounted Cumulative Gain"""
    r = np.asfarray(r)[:k]
    if r.size:
        return np.sum(r / np.log2(np.arange(2, r.size + 2)))
    return 0.0

def ndcg_at_k(r, k):
    """Normalized DCG"""
    best_r = sorted(r, reverse=True)
    return dcg_at_k(r, k) / (dcg_at_k(best_r, k) or 1.0)

def average_precision(ranked_list, relevant_set):
    """AP for multi-label relevance"""
    hits = 0
    sum_precisions = 0
    for i, d in enumerate(ranked_list):
        if d in relevant_set:
            hits += 1
            sum_precisions += hits / (i + 1)
    if len(relevant_set) == 0:
        return 0
    return sum_precisions / len(relevant_set)

def eval_corpus(corpus, gold, k=2):
    dataset_ids = list(corpus.keys())
    tokenized = [corpus[d].lower().split() for d in dataset_ids]
    bm25 = BM25Okapi(tokenized)

    metrics = {
        "Precision@K": [],
        "Recall@K": [],
        "Hit@K": [],
        "MRR": [],
        "nDCG@K": [],
        "MAP": []
    }

    for query, relevant in gold.items():
        relevant = set(relevant)

        # Retrieve ranked list
        scores = bm25.get_scores(query.lower().split())
        ranked = [dataset_ids[i] for i in np.argsort(scores)[::-1]]
        top_k = ranked[:k]

        # Relevance mask for ranking
        relevance_mask = [1 if d in relevant else 0 for d in ranked]

        # Precision and recall
        hits = sum([1 for d in top_k if d in relevant])
        precision = hits / k
        recall = hits / (len(relevant) or 1)

        # Hit@K (boolean)
        hitk = 1 if hits > 0 else 0

        # MRR (first relevant rank)
        rr = 0
        for i, d in enumerate(ranked):
            if d in relevant:
                rr = 1 / (i + 1)
                break

        # nDCG@K
        ndcg = ndcg_at_k(relevance_mask, k)

        # MAP
        ap = average_precision(ranked, relevant)

        # Store
        metrics["Precision@K"].append(precision)
        metrics["Recall@K"].append(recall)
        metrics["Hit@K"].append(hitk)
        metrics["MRR"].append(rr)
        metrics["nDCG@K"].append(ndcg)
        metrics["MAP"].append(ap)

    # Return macro averages as a table
    results_df = pd.DataFrame({
        metric: [np.mean(values)]
        for metric, values in metrics.items()
    })

    return results_df

# %%
baseline_scores = eval_corpus(corpus_baseline, gold)
geo_scores = eval_corpus(corpus_geo, gold)

print(baseline_scores)
print(geo_scores)
